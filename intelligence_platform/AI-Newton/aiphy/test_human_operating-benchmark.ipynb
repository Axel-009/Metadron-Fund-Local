# %% [markdown]
# # Tests with manual selections

# %%
import os
work_dir = os.path.abspath('..')
print(work_dir)
os.chdir(work_dir)
from aiphy.main import Theorist, MeasureType, Exp, ExpStructure, Proposition, Concept, Intrinsic
from aiphy.dataplot import plot_datastruct, plot_data, plot_normaldata, ExpData, NormalData
from aiphy.debugger import Debugger

# Experiment configs can be added here
from aiphy.experiment.basic import (
    motion0_3d_config, motion_3d_config,
    collision_elastic_3body_config, collision_y_config,
    collision_2d_config, collision_nh_config,
)
from aiphy.experiment.ground_laboratory import (
    gravity_config, free_fall_config,
    projectile_config, oblique_projectile_x_config, oblique_projectile_y_config,
    oblique_projectile_config, vertical_projectile_config,
    hanging_spring_1_config, hanging_spring_2_config, hanging_spring_3_config,
    pendulum_oscillation_1_config, pendulum_oscillation_2_config,
    slope_oscillation_1_config, slope_oscillation_2_config,
    projectile_oscillation_1_config, projectile_oscillation_2_config,
)
from aiphy.experiment.oscillation import (
    oscillation_x_1_config, oscillation_x_2_config, oscillation_x_3_config,
    oscillation_2d_1_config, oscillation_2d_2_config, oscillation_2d_3_config,
    oscillation_r_3_config, oscillation_r_4_config,
    oscillation_rot_1_config, oscillation_rot_2_config, oscillation_rot_3_config,
)
from aiphy.experiment.cosmos import (
    celestial_2_xy_config, celestial_2_xz_config, celestial_2_yz_config,
    celestial_3_config, celestial_4_config,
)
# Out:
# /home/dsjian/researches/AI-Newton

# %%
rd = Theorist.read_from_file
wr = Theorist.save_to_file
debug_file = "data/human/jds"

# %% [markdown]
# register experiments

# %%
theorist = Theorist.read_from_file(debug_file)
# Out:
# Knowledge file not found. Use default knowledge.
# Memory file not found. Use default memory.
# Specific model file not found. Use default specific model.
# Registered New Basic Concept: t = (1->Clock) |- t[1]
# Registered New Basic Concept: posx = (1->Particle) |- posx[1]
# Registered New Basic Concept: cz = (1->Slope) |- cz[1]
# Registered New Basic Concept: posy = (1->Particle) |- posy[1]
# Registered New Basic Concept: posz = (1->Particle) |- posz[1]
# Registered New Basic Concept: cy = (1->Slope) |- cy[1]
# Registered New Basic Concept: dist = (1->Particle) (2->Particle) |- dist[1, 2]
# Registered New Basic Concept: cx = (1->Slope) |- cx[1]
# Registered New Basic Concept: length = (1->Spring) |- length[1]
# General law file not found. Use default general laws.

# %%
theorist = Theorist()
# Register imported experiments
theorist.register_experiment(motion0_3d_config())
theorist.register_experiment(motion_3d_config())
theorist.register_experiment(collision_elastic_3body_config())
theorist.register_experiment(collision_y_config())
theorist.register_experiment(collision_2d_config())
theorist.register_experiment(collision_nh_config())

theorist.register_experiment(gravity_config())
theorist.register_experiment(free_fall_config())
theorist.register_experiment(projectile_config())
theorist.register_experiment(oblique_projectile_x_config())
theorist.register_experiment(oblique_projectile_y_config())
theorist.register_experiment(oblique_projectile_config())
theorist.register_experiment(vertical_projectile_config())
theorist.register_experiment(hanging_spring_1_config())
theorist.register_experiment(hanging_spring_2_config())
theorist.register_experiment(hanging_spring_3_config())
theorist.register_experiment(pendulum_oscillation_1_config())
theorist.register_experiment(pendulum_oscillation_2_config())
theorist.register_experiment(slope_oscillation_1_config())
theorist.register_experiment(slope_oscillation_2_config())
theorist.register_experiment(projectile_oscillation_1_config())
theorist.register_experiment(projectile_oscillation_2_config())

theorist.register_experiment(oscillation_x_1_config())
theorist.register_experiment(oscillation_x_2_config())
theorist.register_experiment(oscillation_x_3_config())
theorist.register_experiment(oscillation_2d_1_config())
theorist.register_experiment(oscillation_2d_2_config())
theorist.register_experiment(oscillation_2d_3_config())
theorist.register_experiment(oscillation_r_3_config())
theorist.register_experiment(oscillation_r_4_config())
theorist.register_experiment(oscillation_rot_1_config())
theorist.register_experiment(oscillation_rot_2_config())
theorist.register_experiment(oscillation_rot_3_config())

theorist.register_experiment(celestial_2_xy_config())
theorist.register_experiment(celestial_2_xz_config())
theorist.register_experiment(celestial_2_yz_config())
theorist.register_experiment(celestial_3_config())
theorist.register_experiment(celestial_4_config())
# Out:
# Registered New Basic Concept: t = (1->Clock) |- t[1]
# Registered New Basic Concept: posx = (1->Particle) |- posx[1]
# Registered New Basic Concept: cz = (1->Slope) |- cz[1]
# Registered New Basic Concept: cx = (1->Slope) |- cx[1]
# Registered New Basic Concept: posy = (1->Particle) |- posy[1]
# Registered New Basic Concept: posz = (1->Particle) |- posz[1]
# Registered New Basic Concept: dist = (1->Particle) (2->Particle) |- dist[1, 2]
# Registered New Basic Concept: length = (1->Spring) |- length[1]
# Registered New Basic Concept: cy = (1->Slope) |- cy[1]
# geommetry info in <motion0_3d> Add to Specific model: 100%|██████████| 1/1 [00:00<00:00, 22.65it/s]
# geommetry info in <motion_3d> Add to Specific model: 100%|██████████| 5/5 [00:00<00:00, 33.44it/s]
# geommetry info in <collision_elastic_3body> Add to Specific model: 100%|██████████| 9/9 [00:00<00:00, 113.68it/s]
# geommetry info in <collision_y> Add to Specific model: 100%|██████████| 6/6 [00:00<00:00, 120.80it/s]
# geommetry info in <collision_2d> Add to Specific model: 100%|██████████| 4/4 [00:00<00:00, 69.13it/s]
# geommetry info in <collision_nh> Add to Specific model: 100%|██████████| 4/4 [00:00<00:00, 59.65it/s]
# geommetry info in <gravity> Add to Specific model: 100%|██████████| 3/3 [00:00<00:00, 24.82it/s]
# geommetry info in <free_fall> Add to Specific model: 100%|██████████| 2/2 [00:00<00:00, 74.33it/s]
# geommetry info in <projectile> Add to Specific model: 0it [00:00, ?it/s]
# geommetry info in <oblique_projectile_x> Add to Specific model: 100%|██████████| 1/1 [00:00<00:00, 24.72it/s]
# geommetry info in <oblique_projectile_y> Add to Specific model: 100%|██████████| 1/1 [00:00<00:00, 25.37it/s]
# geommetry info in <oblique_projectile> Add to Specific model: 0it [00:00, ?it/s]
# geommetry info in <vertical_projectile> Add to Specific model: 100%|██████████| 2/2 [00:00<00:00, 64.57it/s]
# geommetry info in <hanging_spring_1> Add to Specific model: 100%|██████████| 3/3 [00:00<00:00, 37.33it/s]
# geommetry info in <hanging_spring_2> Add to Specific model: 100%|██████████| 8/8 [00:05<00:00,  1.39it/s]
# geommetry info in <hanging_spring_3> Add to Specific model: 100%|██████████| 15/15 [00:11<00:00,  1.28it/s]
# geommetry info in <pendulum_oscillation_1> Add to Specific model: 100%|██████████| 2/2 [00:04<00:00,  2.25s/it]
# geommetry info in <pendulum_oscillation_2> Add to Specific model: 100%|██████████| 6/6 [00:20<00:00,  3.47s/it]
# geommetry info in <slope_oscillation_1> Add to Specific model: 100%|██████████| 5/5 [00:11<00:00,  2.33s/it]
# geommetry info in <slope_oscillation_2> Add to Specific model: 100%|██████████| 9/9 [00:49<00:00,  5.51s/it]
# geommetry info in <projectile_oscillation_1> Add to Specific model: 100%|██████████| 3/3 [00:13<00:00,  4.41s/it]
# geommetry info in <projectile_oscillation_2> Add to Specific model: 100%|██████████| 8/8 [00:33<00:00,  4.17s/it]
# geommetry info in <oscillation_x_1> Add to Specific model: 100%|██████████| 7/7 [00:01<00:00,  4.02it/s]
# geommetry info in <oscillation_x_2> Add to Specific model: 100%|██████████| 14/14 [00:03<00:00,  3.70it/s]
# geommetry info in <oscillation_x_3> Add to Specific model: 100%|██████████| 23/23 [00:08<00:00,  2.63it/s]
# geommetry info in <oscillation_2d_1> Add to Specific model: 100%|██████████| 5/5 [00:02<00:00,  1.97it/s]
# geommetry info in <oscillation_2d_2> Add to Specific model: 100%|██████████| 11/11 [00:03<00:00,  3.05it/s]
# geommetry info in <oscillation_2d_3> Add to Specific model: 100%|██████████| 19/19 [00:10<00:00,  1.83it/s]
# geommetry info in <oscillation_r_3> Add to Specific model: 100%|██████████| 12/12 [00:41<00:00,  3.49s/it]
# geommetry info in <oscillation_r_4> Add to Specific model: 100%|██████████| 20/20 [01:35<00:00,  4.80s/it]
# geommetry info in <oscillation_rot_1> Add to Specific model: 100%|██████████| 2/2 [00:01<00:00,  1.34it/s]
# geommetry info in <oscillation_rot_2> Add to Specific model: 100%|██████████| 6/6 [00:10<00:00,  1.82s/it]
# geommetry info in <oscillation_rot_3> Add to Specific model: 100%|██████████| 12/12 [00:24<00:00,  2.02s/it]
# geommetry info in <celestial_2_xy> Add to Specific model: 100%|██████████| 4/4 [00:06<00:00,  1.63s/it]
# geommetry info in <celestial_2_xz> Add to Specific model: 100%|██████████| 4/4 [00:06<00:00,  1.66s/it]
# geommetry info in <celestial_2_yz> Add to Specific model: 100%|██████████| 4/4 [00:06<00:00,  1.64s/it]
# geommetry info in <celestial_3> Add to Specific model: 100%|██████████| 9/9 [00:24<00:00,  2.70s/it]
# geommetry info in <celestial_4> Add to Specific model: 100%|██████████| 16/16 [00:50<00:00,  3.14s/it]

# %% [markdown]
# define alias

# %%
prc = theorist.print_concepts
prg = theorist.print_general_laws
debugger = Debugger(theorist)

# %%
theorist.save_to_file(debug_file)
# Out:
# Saving knowledge to data/human/jds_knowledge.txt

# %% [markdown]
# ## Test: find energy conservation on ground

# %% [markdown]
# ### find intrinsic: **oringinal length** of a spring

# %%
t = debugger.check_concept_discovered(Concept("(1->Clock) |- t[1]"), "t")
len = debugger.check_concept_discovered(Concept("(1->Spring) |- length[1]"), "len")
posx = debugger.check_concept_discovered(Concept("(1->Particle) |- posx[1]"), "posx")
posy = debugger.check_concept_discovered(Concept("(1->Particle) |- posy[1]"), "posy")
posz = debugger.check_concept_discovered(Concept("(1->Particle) |- posz[1]"), "posz")
dist = debugger.check_concept_discovered(Concept("(1->Particle) (2->Particle) |- dist[1, 2]"), "dist")

t, len, posx, posy, posz, dist
# Out:
# (t, length, posx, posy, posz, dist)

# %%
debugger.work("stringmotion0", name_list=[len, posx, t])
theorist.save_to_file(debug_file)
# Out:
# ########## stringmotion0 ##########
#
#
# Process ID: 1943844 of experiment stringmotion0
# Selected concepts: ['t', 'length']
# Try to complete invalid general laws
# Finish trying to complete incomplete general laws
# Fixing general laws.
# Try to convert conserved general laws to zero ones
# Finish trying to convert conserved general laws to zero ones
# Found 7 relations
# Begin filtering relations
# After filtering, 1 relations left
# Propose new proposition: length[1] is conserved
# Add to Specific model: 100%|██████████| 1/1 [00:00<00:00, 40.56it/s]
# Reducing 1 conclusions
# Reduce Conclusions: 100%|██████████| 1/1 [00:00<00:00, 13.33it/s]
# Insert to ideal: length[1] is conserved
# calc_relations between  {'P1'}
# Found 0 relations between conserved quantities
# Reducing 1 conclusions
# Reduce Conclusions: 100%|██████████| 1/1 [00:00<00:00, 14.97it/s]
# Insert to ideal: length[1] is conserved
# Fixing general laws.
# Found intrinsic relation: length[1] with relevant_id = [1]
# Registered New Onebody Intrinsic Concept: C_01 = [#stringmotion0 (1->Spring) |- length[1]]
# Registered New Concept: C_01 = [#stringmotion0 (1->Spring) |- length[1]]
# Total rewards: 2
# Saving knowledge to data/human/jds_knowledge.txt

# %%
freel = debugger.check_concept_discovered(Intrinsic(f"[#stringmotion0 (1->Spring) |- {len(1)}]"), "freel")
freel
# Out:
# C_01

# %% [markdown]
# ### find dynamic: **strach length** (may with a minus) of a spring

# %%
debugger.work("stringmotion0", intrinsic_mode=1, name_list=[len, t])
theorist.save_to_file(debug_file)
# Out:
# ########## stringmotion0 ##########
#
#
# Process ID: 1943844 of experiment stringmotion0
# Selected concepts: ['t', 'length']
# Try to complete invalid general laws
# Finish trying to complete incomplete general laws
# Fixing general laws.
# Try to convert conserved general laws to zero ones
# Finish trying to convert conserved general laws to zero ones
# Found 7 relations
# Begin filtering relations
# After filtering, 0 relations left
# Add to Specific model: 0it [00:00, ?it/s]
# Reducing 1 conclusions
# Reduce Conclusions: 100%|██████████| 1/1 [00:00<00:00, 15.38it/s]
# Insert to ideal: length[1] is conserved
# calc_relations between  {'C_01[1]', 'P1'}
# Found 2 relations between conserved quantities
# Reducing 2 conclusions
# Reduce Conclusions:   0%|          | 0/2 [00:00<?, ?it/s]
# Insert to ideal: length[1] is conserved
# Reduce Conclusions: 100%|██████████| 2/2 [00:00<00:00,  9.61it/s]
# Insert to ideal: (length[1] + (-1 * C_01[1])) is zero
# Possible general law: (1->Spring) |- (length[1] + (-1 * C_01[1])) is IsZero. Register it as both concept and law.
# Registered New Concept: C_02 = (1->Spring) |- (length[1] + (-1 * C_01[1]))
# Fixing general laws.
# Found intrinsic relation: length[1] with relevant_id = [1]
# Total rewards: 1
# Saving knowledge to data/human/jds_knowledge.txt

# %%
deltax = debugger.check_concept_discovered(len-freel, "deltax")
deltax
# Out:
# C_02

# %% [markdown]
# ### find intrinsic: **mass** (may be with a minus) of a particle

# %%
debugger.work("gravity", intrinsic_mode=1, name_list=[deltax])
theorist.save_to_file(debug_file)
# Out:
# ########## gravity ##########
#
#
# Process ID: 1943844 of experiment gravity
# Selected concepts: ['C_02']
# Try to complete invalid general laws
# Finish trying to complete incomplete general laws
# Fixing general laws.
# Try to convert conserved general laws to zero ones
# Finish trying to convert conserved general laws to zero ones
# Found 1 relations
# Begin filtering relations
# After filtering, 4 relations left
# Propose new proposition: posy[1] is zero
# Propose new proposition: posx[1] is zero
# Propose new proposition: (posz[1] + length[2]) is conserved
# Propose new proposition: C_02[2] is conserved
# Add to Specific model: 100%|██████████| 4/4 [00:00<00:00, 22.25it/s]
# Reducing 4 conclusions
# Reduce Conclusions:   0%|          | 0/4 [00:00<?, ?it/s]
# Insert to ideal: posx[1] is zero
# Reduce Conclusions:  25%|██▌       | 1/4 [00:00<00:01,  2.36it/s]
# Insert to ideal: posy[1] is zero
# Reduce Conclusions:  50%|█████     | 2/4 [00:00<00:00,  2.44it/s]
# Insert to ideal: (posz[1] + length[2]) is conserved
# Reduce Conclusions: 100%|██████████| 4/4 [00:01<00:00,  3.03it/s]
# Insert to ideal: C_02[2] is conserved
# calc_relations between  {'C_01[2]', 'P4', 'P1'}
# Found 2 relations between conserved quantities
# Reducing 4 conclusions
# Reduce Conclusions:   0%|          | 0/4 [00:00<?, ?it/s]
# Insert to ideal: posx[1] is zero
# Reduce Conclusions:  25%|██▌       | 1/4 [00:00<00:01,  2.54it/s]
# Insert to ideal: posy[1] is zero
# Reduce Conclusions:  50%|█████     | 2/4 [00:00<00:00,  2.55it/s]
# Insert to ideal: (posz[1] + length[2]) is conserved
# Reduce Conclusions: 100%|██████████| 4/4 [00:01<00:00,  3.19it/s]
# Insert to ideal: C_02[2] is conserved
# Possible general law: (1->Spring) |- C_02[1] is IsConserved. Register it as both concept and law.
# Fixing general laws.
# Found intrinsic relation: C_02[2] with relevant_id = [1]
# Registered New Onebody Intrinsic Concept: C_06 = [#gravity (1->Particle) |- C_02[2]]
# Registered New Concept: C_06 = [#gravity (1->Particle) |- C_02[2]]
# Found intrinsic relation: ((posz[1] + length[2]) + (-1 * C_02[2])) with relevant_id = [2]
# Found intrinsic relation: (C_01[2] + (-1 * (posz[1] + length[2]))) with relevant_id = [1]
# Total rewards: 2
# Saving knowledge to data/human/jds_knowledge.txt

# %%
mass = debugger.check_concept_discovered(Intrinsic(f"[#gravity (1->Particle) |- {deltax(2)}]"), "mass")
mass
# Out:
# C_06

# %% [markdown]
# ### find dynamic: $v_x$, $v_y$, $a_x$ and $a_y$ of a particle

# %%
debugger.work("motion0_3d", name_list=[posx, posy, posz, t])
theorist.save_to_file(debug_file)
# Out:
# ########## motion0_3d ##########
#
#
# Process ID: 1943844 of experiment motion0_3d
# Selected concepts: ['t', 'posy', 'posx']
# Try to complete invalid general laws
# Finish trying to complete incomplete general laws
# Fixing general laws.
# Try to convert conserved general laws to zero ones
# Finish trying to convert conserved general laws to zero ones
# Registered New Concept: C_07 = (1->Particle) |- D[posy[1]]/D[t[0]]
# Possible general law: (1->Particle) |- D[C_07[1]]/D[t[0]] is IsZero. Register it as both concept and law.
# Registered New Concept: C_08 = (1->Particle) |- D[C_07[1]]/D[t[0]]
# Registered new general law: R_01 = GeneralLaw(name=R_01, type=IsZero, indication=ForAll, prop=(1->Particle) |- C_08[1] is zero, valid_experiments=['motion0_3d', 'motion', 'collision', 'oscillation', 'motion0', 'motion0y', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'collision_nh', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'hanging_spring_1', 'hanging_spring_2', 'hanging_spring_3', 'pendulum_oscillation_1', 'pendulum_oscillation_2', 'oscillation_x_1', 'oscillation_x_2', 'oscillation_x_3', 'celestial_2_xz'], father=None)
# Registered New Concept: C_09 = (1->Particle) |- D[posx[1]]/D[t[0]]
# Possible general law: (1->Particle) |- D[C_09[1]]/D[t[0]] is IsZero. Register it as both concept and law.
# Registered New Concept: C_10 = (1->Particle) |- D[C_09[1]]/D[t[0]]
# Registered new general law: R_02 = GeneralLaw(name=R_02, type=IsZero, indication=ForAll, prop=(1->Particle) |- C_10[1] is zero, valid_experiments=['motion0_3d', 'collision', 'motiony', 'oscillationy', 'motion0', 'motion0y', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'collision_nh', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'hanging_spring_1', 'hanging_spring_2', 'hanging_spring_3', 'celestial_2_yz'], father=None)
# Found 20 relations
# Begin filtering relations
# After filtering, 3 relations left
# Propose new proposition: posz[1] is zero
# Propose new proposition: D[posx[1]]/D[t[0]] is conserved
# Propose new proposition: D[posy[1]]/D[t[0]] is conserved
# Add to Specific model: 100%|██████████| 3/3 [00:00<00:00, 15.27it/s]
# Reducing 3 conclusions
# Reduce Conclusions:   0%|          | 0/3 [00:00<?, ?it/s]
# Insert to ideal: posz[1] is zero
# Reduce Conclusions:  33%|███▎      | 1/3 [00:00<00:00,  2.43it/s]
# Insert to ideal: D[posx[1]]/D[t[0]] is conserved
# Reduce Conclusions: 100%|██████████| 3/3 [00:01<00:00,  2.16it/s]
# Insert to ideal: D[posy[1]]/D[t[0]] is conserved
# calc_relations between  {'P2', 'P3', 'C_06[1]'}
# Found 0 relations between conserved quantities
# Reducing 3 conclusions
# Reduce Conclusions:   0%|          | 0/3 [00:00<?, ?it/s]
# Insert to ideal: posz[1] is zero
# Reduce Conclusions:  33%|███▎      | 1/3 [00:00<00:00,  2.52it/s]
# Insert to ideal: D[posx[1]]/D[t[0]] is conserved
# Reduce Conclusions: 100%|██████████| 3/3 [00:01<00:00,  2.19it/s]
# Insert to ideal: D[posy[1]]/D[t[0]] is conserved
# Fixing general laws.
# Try to reduce R_01
# --- R_01 is marked as useful
# Update diffalg for existing marked general laws
# Finish updating diffalg
# Try to reduce R_02
# --- R_02 is marked as useful
# Update diffalg for existing marked general laws
# Finish updating diffalg
# Total rewards: 4
# Saving knowledge to data/human/jds_knowledge.txt

# %%
vx = debugger.check_concept_discovered(posx.diff(), "vx")
vy = debugger.check_concept_discovered(posy.diff(), "vy")
ax = debugger.check_concept_discovered(vx.diff(1), "ax")
ay = debugger.check_concept_discovered(vy.diff(1), "ay")
vx, vy, ax, ay
# Out:
# (C_09, C_07, C_10, C_08)

# %%
prop_ax = debugger.check_law(ax.gen_prop("Zero"))
prop_ax
# Out:
# 'R_02'

# %%
prop_ay = debugger.check_law(ay.gen_prop("Zero"))
prop_ay
# Out:
# 'R_01'

# %% [markdown]
# ### find dynamic: $v_z$ and $a_z$ of a particle

# %%
debugger.work("motion_3d", name_list=[vx, posx, posy, posz, t])
theorist.save_to_file(debug_file)
# Out:
# ########## motion_3d ##########
#
#
# Process ID: 1943844 of experiment motion_3d
# Selected concepts: ['posx', 'C_09', 'posz', 't', 'posy']
# Try to complete invalid general laws
# - Try to complete R_01
# - Try to complete R_02
# Finish trying to complete incomplete general laws
# Fixing general laws.
# Try to convert conserved general laws to zero ones
# Finish trying to convert conserved general laws to zero ones
# Registered New Concept: C_14 = (1->Particle) |- D[posz[1]]/D[t[0]]
# Found 58 relations
# Begin filtering relations
# After filtering, 13 relations left
# Propose new proposition: cy[2] is conserved
# Propose new proposition: cx[2] is conserved
# Propose new proposition: cz[2] is conserved
# Propose new proposition: D[C_14[1]]/D[t[0]] is conserved
# Propose new proposition: D[C_09[1]]/D[t[0]] is conserved
# Propose new proposition: D[posy[1]]/D[posx[1]] is conserved
# Propose new proposition: D[posz[1]]/D[posx[1]] is conserved
# Propose new proposition: D[posy[1]]/D[posz[1]] is conserved
# Propose new proposition: ((cy[2] * posx[1]) - (cx[2] * posy[1])) is conserved
# Propose new proposition: (((cx[2] * posx[1]) + (cy[2] * posy[1])) + (cz[2] * posz[1])) is conserved
# Propose new proposition: D[(C_09[1] * C_09[1])]/D[posz[1]] is conserved
# Propose new proposition: D[(C_09[1] * C_09[1])]/D[posy[1]] is conserved
# Propose new proposition: D[(C_09[1] * C_09[1])]/D[posx[1]] is conserved
# Add to Specific model: 100%|██████████| 13/13 [00:00<00:00, 19.88it/s]
# Reducing 13 conclusions
# Reduce Conclusions:   0%|          | 0/13 [00:00<?, ?it/s]
# Insert to ideal: cx[2] is conserved
# Reduce Conclusions:   8%|▊         | 1/13 [00:00<00:06,  1.89it/s]
# Insert to ideal: cy[2] is conserved
# Reduce Conclusions:  15%|█▌        | 2/13 [00:01<00:05,  1.90it/s]
# Insert to ideal: cz[2] is conserved
# Reduce Conclusions:  23%|██▎       | 3/13 [00:01<00:05,  1.95it/s]
# Insert to ideal: D[C_14[1]]/D[t[0]] is conserved
# Reduce Conclusions:  31%|███       | 4/13 [00:02<00:05,  1.60it/s]
# Insert to ideal: D[C_09[1]]/D[t[0]] is conserved
# Reduce Conclusions:  38%|███▊      | 5/13 [00:03<00:06,  1.24it/s]
# Insert to ideal: D[posy[1]]/D[posx[1]] is conserved
# Reduce Conclusions:  46%|████▌     | 6/13 [00:04<00:06,  1.08it/s]
# Insert to ideal: D[posz[1]]/D[posx[1]] is conserved
# Reduce Conclusions:  54%|█████▍    | 7/13 [00:06<00:05,  1.01it/s]
# Insert to ideal: ((cy[2] * posx[1]) - (cx[2] * posy[1])) is conserved
# Reduce Conclusions:  69%|██████▉   | 9/13 [00:07<00:03,  1.28it/s]
# Insert to ideal: (((cx[2] * posx[1]) + (cy[2] * posy[1])) + (cz[2] * posz[1])) is conserved
# Reduce Conclusions: 100%|██████████| 13/13 [00:07<00:00,  1.63it/s]
# calc_relations between  {'P8', 'P7', 'P5', 'P2', 'P6', 'C_06[1]', 'P1', 'P4', 'P3', 'P9'}
# Found 0 relations between conserved quantities
# Reducing 9 conclusions
# Reduce Conclusions:   0%|          | 0/9 [00:00<?, ?it/s]
# Insert to ideal: cx[2] is conserved
# Reduce Conclusions:  11%|█         | 1/9 [00:00<00:03,  2.16it/s]
# Insert to ideal: cy[2] is conserved
# Reduce Conclusions:  22%|██▏       | 2/9 [00:01<00:03,  2.12it/s]
# Insert to ideal: cz[2] is conserved
# Reduce Conclusions:  33%|███▎      | 3/9 [00:01<00:02,  2.17it/s]
# Insert to ideal: D[C_14[1]]/D[t[0]] is conserved
# Reduce Conclusions:  44%|████▍     | 4/9 [00:02<00:02,  1.75it/s]
# Insert to ideal: D[C_09[1]]/D[t[0]] is conserved
# Reduce Conclusions:  56%|█████▌    | 5/9 [00:03<00:02,  1.57it/s]
# Insert to ideal: D[posy[1]]/D[posx[1]] is conserved
# Reduce Conclusions:  67%|██████▋   | 6/9 [00:03<00:02,  1.50it/s]
# Insert to ideal: D[posz[1]]/D[posx[1]] is conserved
# Reduce Conclusions:  78%|███████▊  | 7/9 [00:04<00:01,  1.46it/s]
# Insert to ideal: ((cy[2] * posx[1]) - (cx[2] * posy[1])) is conserved
# Reduce Conclusions: 100%|██████████| 9/9 [00:05<00:00,  1.66it/s]
# Insert to ideal: (((cx[2] * posx[1]) + (cy[2] * posy[1])) + (cz[2] * posz[1])) is conserved
# Possible general law: (1->Particle) |- D[C_14[1]]/D[t[0]] is IsConserved. Register it as both concept and law.
# Registered New Concept: C_16 = (1->Particle) |- D[C_14[1]]/D[t[0]]
# Registered new general law: R_03 = GeneralLaw(name=R_03, type=IsConserved, indication=ForAll, prop=(1->Particle) |- C_16[1] is conserved, valid_experiments=['motion_3d', 'motion', 'collision', 'oscillation', 'motiony', 'oscillationy', 'motion0', 'motion0y', 'motion0_3d', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'collision_nh', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'oscillation_x_1', 'oscillation_x_2', 'oscillation_x_3', 'oscillation_2d_1', 'oscillation_2d_2', 'oscillation_2d_3', 'oscillation_r_3', 'oscillation_r_4', 'oscillation_rot_1', 'oscillation_rot_2', 'oscillation_rot_3', 'celestial_2_xy', 'celestial_3', 'celestial_4'], father=None)
# Possible general law: (1->Particle) |- D[C_09[1]]/D[t[0]] is IsConserved. Register it as both concept and law.
# Registered new general law: R_04 = GeneralLaw(name=R_04, type=IsConserved, indication=ForAll, prop=(1->Particle) |- C_10[1] is conserved, valid_experiments=['motion_3d', 'motion', 'collision', 'motiony', 'oscillationy', 'motion0', 'motion0y', 'motion0_3d', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'collision_nh', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'hanging_spring_1', 'hanging_spring_2', 'hanging_spring_3', 'celestial_2_yz'], father=None)
# Fixing general laws.
# Try to reduce R_03
# --- R_03 is marked as useful
# Update diffalg for existing marked general laws
# Finish updating diffalg
# Total rewards: 5
# Saving knowledge to data/human/jds_knowledge.txt

# %%
vz = debugger.check_concept_discovered(posz.diff(1), "vz")
az = debugger.check_concept_discovered(vz.diff(1), "az")
vz, az
# Out:
# (C_14, C_16)

# %%
prop_az = debugger.check_law(az.gen_prop("Conserved"))
prop_az
# Out:
# 'R_03'

# %% [markdown]
# ### find general conclusion: $\sum_{i\in\text{particles}}m_iv^{2}_{x,i}=\text{const.}$, $\sum_{i\in\text{particles}}m_iv_{x,i}=\text{const.}$
#
# (head of energy conservation)

# %%
debugger.work("collision", name_list=[mass, vx, vy, vz])
theorist.save_to_file(debug_file)
# Out:
# ########## collision ##########
#
#
# Process ID: 1943844 of experiment collision
# Selected concepts: ['C_06', 'C_09']
# Try to complete invalid general laws
# Finish trying to complete incomplete general laws
# Fixing general laws.
# Try to convert conserved general laws to zero ones
# Finish trying to convert conserved general laws to zero ones
# Found 31 relations
# Begin filtering relations
# After filtering, 9 relations left
# Propose new proposition: posz[2] is zero
# Propose new proposition: posy[2] is zero
# Propose new proposition: posy[1] is zero
# Propose new proposition: posz[1] is zero
# Propose new proposition: (dist[1, 2] - dist[2, 1]) is zero
# Propose new proposition: ((dist[1, 2] ** 2) - ((posx[1] - posx[2]) ** 2)) is zero
# Propose new proposition: ((C_06[1] * C_09[1]) + (C_06[2] * C_09[2])) is conserved
# Propose new proposition: ((C_06[1] * (C_09[1] ** 2)) + (C_06[2] * (C_09[2] ** 2))) is conserved
# Propose new proposition: (((C_09[1] ** 2) / C_06[2]) + ((C_09[2] ** 2) / C_06[1])) is conserved
# Add to Specific model: 100%|██████████| 9/9 [00:00<00:00, 35.70it/s]
# Reducing 9 conclusions
# Reduce Conclusions:   0%|          | 0/9 [00:00<?, ?it/s]
# Insert to ideal: posz[2] is zero
# Reduce Conclusions:  11%|█         | 1/9 [00:00<00:03,  2.48it/s]
# Insert to ideal: posy[2] is zero
# Reduce Conclusions:  22%|██▏       | 2/9 [00:00<00:02,  2.45it/s]
# Insert to ideal: posy[1] is zero
# Reduce Conclusions:  33%|███▎      | 3/9 [00:01<00:02,  2.46it/s]
# Insert to ideal: posz[1] is zero
# Reduce Conclusions:  44%|████▍     | 4/9 [00:01<00:02,  2.41it/s]
# Insert to ideal: (dist[1, 2] - dist[2, 1]) is zero
# Reduce Conclusions:  56%|█████▌    | 5/9 [00:02<00:01,  2.42it/s]
# Insert to ideal: ((dist[1, 2] ** 2) - ((posx[1] - posx[2]) ** 2)) is zero
# Reduce Conclusions:  67%|██████▋   | 6/9 [00:02<00:01,  2.38it/s]
# Insert to ideal: ((C_06[1] * C_09[1]) + (C_06[2] * C_09[2])) is conserved
# Reduce Conclusions:  78%|███████▊  | 7/9 [00:03<00:01,  1.93it/s]
# Insert to ideal: ((C_06[1] * (C_09[1] ** 2)) + (C_06[2] * (C_09[2] ** 2))) is conserved
# Reduce Conclusions: 100%|██████████| 9/9 [00:04<00:00,  2.07it/s]
# calc_relations between  {'P8', 'C_06[2]', 'C_06[1]', 'P7'}
# Found 0 relations between conserved quantities
# Reducing 8 conclusions
# Reduce Conclusions:   0%|          | 0/8 [00:00<?, ?it/s]
# Insert to ideal: posz[2] is zero
# Reduce Conclusions:  12%|█▎        | 1/8 [00:00<00:02,  2.38it/s]
# Insert to ideal: posy[2] is zero
# Reduce Conclusions:  25%|██▌       | 2/8 [00:00<00:02,  2.39it/s]
# Insert to ideal: posy[1] is zero
# Reduce Conclusions:  38%|███▊      | 3/8 [00:01<00:02,  2.42it/s]
# Insert to ideal: posz[1] is zero
# Reduce Conclusions:  50%|█████     | 4/8 [00:01<00:01,  2.40it/s]
# Insert to ideal: (dist[1, 2] - dist[2, 1]) is zero
# Reduce Conclusions:  62%|██████▎   | 5/8 [00:02<00:01,  2.43it/s]
# Insert to ideal: ((dist[1, 2] ** 2) - ((posx[1] - posx[2]) ** 2)) is zero
# Reduce Conclusions:  75%|███████▌  | 6/8 [00:02<00:00,  2.42it/s]
# Insert to ideal: ((C_06[1] * C_09[1]) + (C_06[2] * C_09[2])) is conserved
# Reduce Conclusions: 100%|██████████| 8/8 [00:03<00:00,  2.21it/s]
# Insert to ideal: ((C_06[1] * (C_09[1] ** 2)) + (C_06[2] * (C_09[2] ** 2))) is conserved
# Possible general law: [Sum:Particle] (1->Particle) |- (C_06[1] * (C_09[1] ** 2)) is IsConserved. Register it as both concept and law.
# Registered New Concept: C_20 = [Sum:Particle] (1->Particle) |- (C_06[1] * (C_09[1] ** 2))
# Registered new general law: R_05 = GeneralLaw(name=R_05, type=IsConserved, indication=Sum, prop=|- C_20 is conserved, valid_experiments=['collision', 'motiony', 'oscillationy', 'stringmotion0', 'motion0', 'motion0y', 'motion0_3d', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'hanging_spring_1', 'hanging_spring_2', 'hanging_spring_3', 'celestial_2_yz'], father=None)
# Possible general law: [Sum:Particle] (1->Particle) |- (C_06[1] * C_09[1]) is IsConserved. Register it as both concept and law.
# Registered New Concept: C_21 = [Sum:Particle] (1->Particle) |- (C_06[1] * C_09[1])
# Registered new general law: R_06 = GeneralLaw(name=R_06, type=IsConserved, indication=Sum, prop=|- C_21 is conserved, valid_experiments=['collision', 'motiony', 'oscillationy', 'stringmotion0', 'motion0', 'motion0y', 'motion0_3d', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'collision_nh', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'hanging_spring_1', 'hanging_spring_2', 'hanging_spring_3', 'projectile_oscillation_1', 'projectile_oscillation_2', 'oscillation_x_1', 'oscillation_x_2', 'oscillation_x_3', 'oscillation_2d_1', 'oscillation_2d_2', 'oscillation_2d_3', 'oscillation_r_3', 'oscillation_r_4', 'celestial_2_xy', 'celestial_2_xz', 'celestial_2_yz', 'celestial_3', 'celestial_4'], father=None)
# Fixing general laws.
# Registered New Concept: C_22 = (1->Particle) |- (C_06[1] * (C_09[1] ** 2))
# Registered New Concept: C_24 = (1->Particle) |- (C_06[1] * C_09[1])
# Try to reduce R_06
# --- R_06 is marked as useful
# Update diffalg for existing marked general laws
# Check if R_02 should be removed
# Finish updating diffalg
# Try to reduce R_05
# --- R_05 is marked as useful
# Update diffalg for existing marked general laws
# Finish updating diffalg
# Total rewards: 10
# Saving knowledge to data/human/jds_knowledge.txt

# %%
px = debugger.check_concept_discovered(mass*vx, "px")
tx = debugger.check_concept_discovered(mass*vx**2, "tx")
px, tx
# Out:
# (C_24, C_22)

# %%
sum_px = debugger.check_concept_discovered(px.mksum('Particle'), "sum_px")
sum_tx = debugger.check_concept_discovered(tx.mksum('Particle'), "sum_tx")
sum_px, sum_tx
# Out:
# (C_21, C_20)

# %% [markdown]
# ### find intrinsic: **elastic coefficient** of a spring

# %%
debugger.work("oscillation", intrinsic_mode=1, name_list=[mass, deltax, ax])
theorist.save_to_file(debug_file)
# Out:
# ########## oscillation ##########
#
#
# Process ID: 1943844 of experiment oscillation
# Selected concepts: ['C_02', 'C_06', 'C_10']
# Try to complete invalid general laws
# - Try to complete R_02
# - Try to complete R_05
# - Try to complete R_06
# Finish trying to complete incomplete general laws
# Fixing general laws.
# Try to convert conserved general laws to zero ones
# Finish trying to convert conserved general laws to zero ones
# Found 26 relations
# Begin filtering relations
# After filtering, 10 relations left
# Propose new proposition: posz[1] is zero
# Propose new proposition: posy[1] is zero
# Propose new proposition: (length[2] - posx[1]) is conserved
# Propose new proposition: (C_10[1] / C_02[2]) is conserved
# Propose new proposition: ((C_06[1] * C_10[1]) / C_02[2]) is conserved
# Propose new proposition: ((C_02[2] * C_06[1]) / C_10[1]) is conserved
# Propose new proposition: ((C_06[1] * C_10[1]) / (C_02[2] * C_06[1])) is conserved
# Propose new proposition: ((C_02[2] * C_10[1]) / (C_02[2] * C_02[2])) is conserved
# Propose new proposition: ((C_10[1] * C_10[1]) / (C_02[2] * C_02[2])) is conserved
# Propose new proposition: ((C_10[1] * C_10[1]) / (C_02[2] * C_10[1])) is conserved
# Add to Specific model: 100%|██████████| 10/10 [00:00<00:00, 17.47it/s]
# Reducing 7 conclusions
# Reduce Conclusions:   0%|          | 0/7 [00:00<?, ?it/s]
# Insert to ideal: posz[1] is zero
# Reduce Conclusions:  14%|█▍        | 1/7 [00:00<00:02,  2.11it/s]
# Insert to ideal: posy[1] is zero
# Reduce Conclusions:  29%|██▊       | 2/7 [00:01<00:02,  2.17it/s]
# Insert to ideal: (length[2] - posx[1]) is conserved
# Reduce Conclusions:  43%|████▎     | 3/7 [00:01<00:01,  2.15it/s]
# Insert to ideal: (C_10[1] / C_02[2]) is conserved
# Reduce Conclusions: 100%|██████████| 7/7 [00:02<00:00,  2.82it/s]
# calc_relations between  {'C_01[2]', 'P3', 'C_06[1]', 'P4'}
# Found 1 relations between conserved quantities
# Reducing 4 conclusions
# Reduce Conclusions:   0%|          | 0/4 [00:00<?, ?it/s]
# Insert to ideal: posz[1] is zero
# Reduce Conclusions:  25%|██▌       | 1/4 [00:00<00:01,  2.48it/s]
# Insert to ideal: posy[1] is zero
# Reduce Conclusions:  50%|█████     | 2/4 [00:00<00:00,  2.50it/s]
# Insert to ideal: (length[2] - posx[1]) is conserved
# Reduce Conclusions: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Insert to ideal: (C_10[1] / C_02[2]) is conserved
# Fixing general laws.
# Registered New Concept: C_26 = (1->Particle) (2->Spring) |- (C_10[1] / C_02[2])
# Found intrinsic relation: ((C_10[1] / C_02[2]) * C_06[1]) with relevant_id = [2]
# Registered New Onebody Intrinsic Concept: C_27 = [#oscillation (2->Spring) |- ((C_10[1] / C_02[2]) * C_06[1])]
# Registered New Concept: C_27 = [#oscillation (2->Spring) |- ((C_10[1] / C_02[2]) * C_06[1])]
# Total rewards: 5
# Saving knowledge to data/human/jds_knowledge.txt

# %%
k = debugger.check_concept_discovered(Intrinsic(f"[#oscillation (2->Spring) |- -{ax(1)/(deltax(2)/mass(1))}]"), "k")
k
# Out:
# -C_27

# %% [markdown]
# ### find general conclusion: $\sum_{i\in\text{particles}}T_{x,i}+\sum_{i\in\text{springs}}V^{(\text{spring})}_{i}=\text{const.}$
#
# ### find general conclusion: $\forall i\in\text{particles},\,a_{x,i}+\frac{1}{m_i}\frac{\partial \sum_{j\in\text{springs}}V^{(\text{spring})}_{j}}{\partial x_i}=0.$

# %%
debugger.work("oscillation", name_list=[ax, deltax], intrinsic_mode=1)
theorist.save_to_file("data/human/jds")
# Out:
# ########## oscillation ##########
#
#
# Process ID: 1943844 of experiment oscillation
# Selected concepts: ['C_02', 'C_10']
# Try to complete invalid general laws
# - Try to complete R_02
# - Try to complete R_05
# Registered New Concept: C_28 = [Sum:Spring] (1->Spring) |- (C_27[1] * (C_02[1] ** 2))
# Registered new general law: R_07 = GeneralLaw(name=R_07, type=IsConserved, indication=Sum, prop=|- (C_20 + (-1 * C_28)) is conserved, valid_experiments=['oscillation'], father=R_05)
# - Try to complete R_06
# Finish trying to complete incomplete general laws
# Fixing general laws.
# Try to complete invalid general laws again
# - Try to complete R_02
# Registered new general law: R_08 = GeneralLaw(name=R_08, type=IsZero, indication=ForAll, prop=(1->Particle) |- ((2 * C_10[1]) + (-1 * (Partial[C_28]/Partial[posx[1]] * (C_06[1] ** -1)))) is zero, valid_experiments=['oscillation'], father=R_02)
# - Try to complete R_06
# Finish trying to complete incomplete general laws
# Fixing general laws.
# Try to convert conserved general laws to zero ones
# Finish trying to convert conserved general laws to zero ones
# Found 12 relations
# Begin filtering relations
# After filtering, 3 relations left
# Propose new proposition: posz[1] is zero
# Propose new proposition: posy[1] is zero
# Propose new proposition: (length[2] - posx[1]) is conserved
# Add to Specific model: 100%|██████████| 3/3 [00:00<00:00, 14463.12it/s]
# Reducing 4 conclusions
# Reduce Conclusions:   0%|          | 0/4 [00:00<?, ?it/s]
# Insert to ideal: posz[1] is zero
# Reduce Conclusions:  25%|██▌       | 1/4 [00:00<00:01,  2.35it/s]
# Insert to ideal: posy[1] is zero
# Reduce Conclusions:  50%|█████     | 2/4 [00:00<00:00,  2.65it/s]
# Insert to ideal: (length[2] - posx[1]) is conserved
# Reduce Conclusions: 100%|██████████| 4/4 [00:01<00:00,  2.63it/s]
# Insert to ideal: (C_10[1] / C_02[2]) is conserved
# calc_relations between  {'C_01[2]', 'C_27[2]', 'P3', 'C_06[1]', 'P4'}
# Found 2 relations between conserved quantities
# Reducing 4 conclusions
# Reduce Conclusions:   0%|          | 0/4 [00:00<?, ?it/s]
# Insert to ideal: posz[1] is zero
# Reduce Conclusions:  25%|██▌       | 1/4 [00:00<00:01,  2.48it/s]
# Insert to ideal: posy[1] is zero
# Reduce Conclusions:  50%|█████     | 2/4 [00:00<00:00,  2.54it/s]
# Insert to ideal: (length[2] - posx[1]) is conserved
# Reduce Conclusions: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Insert to ideal: (C_10[1] / C_02[2]) is conserved
# Fixing general laws.
# Found intrinsic relation: ((C_10[1] / C_02[2]) / C_27[2]) with relevant_id = [1]
# Try to reduce R_07
# --- R_07 is marked as useful
# Update diffalg for existing marked general laws
# Finish updating diffalg
# Try to reduce R_08
# --- R_08 is marked as useful
# Update diffalg for existing marked general laws
# Check if R_02 should be removed
# Finish updating diffalg
# Total rewards: 2
# Saving knowledge to data/human/jds_knowledge.txt

# %% [markdown]
# inspect which experiments are now not covered by energy conservation

# %%
sum_vspring = debugger.check_concept_discovered((k*deltax**2).mksum('Spring'), 'sum_vspring')
sum_vspring
# Out:
# -C_28

# %%
prop_tx_vk = debugger.check_law((sum_tx + sum_vspring).gen_prop("Conserved"))
prop_tx_vk
# Out:
# 'R_07'

# %%
print(debugger.law_info(prop_tx_vk))
# Out:
# GeneralLaw(name=R_07, type=IsConserved, indication=Sum, prop=|- (C_20 + (-1 * C_28)) is conserved, valid_experiments=['oscillation', 'collision', 'motiony', 'stringmotion0', 'motion0', 'motion0y', 'motion0_3d', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'oscillation_x_1', 'oscillation_x_2', 'oscillation_x_3', 'celestial_2_yz'], father=R_05)
# |- (C_20 + (-1 * C_28)) is conserved
# |- (C_20 + (-1 * C_28)) is conserved
# Not valid experiments: [celestial_3, slope_oscillation_1, oscillation_r_3, oscillation_2d_3, projectile_oscillation_1, oscillation_2d_2, oscillation_2d_1, motion, oscillation_r_4, oscillationy, motion_3d, pendulum_oscillation_1, oscillation_rot_2, hanging_spring_2, celestial_4, oscillation_rot_3, celestial_2_xz, celestial_2_xy, projectile_oscillation_2, pendulum_oscillation_2, collision_nh, hanging_spring_1, oscillation_rot_1, slope_oscillation_2, hanging_spring_3]

# %%
temp_expr = 2 * ax(1) + Exp.Partial(sum_vspring(), posx(1).unwrap_atom) / mass(1)
prop_ax_partvk = debugger.check_law(f"(1->Particle) |- {temp_expr} is zero")
prop_ax_partvk
# Out:
# 'R_08'

# %%
debugger.sympy_raw_definition(temp_expr, "oscillation")
# Out:
# 2*Derivative(posx_1(t_0), (t_0, 2)) - C_27_2*(-2*C_01_2 + 2*length_2(t_0))/C_06_1

# %% [markdown]
# inspect which experiments are now not covered by Newton's second law in x direction now

# %%
print(debugger.law_info(prop_ax_partvk))
# Out:
# GeneralLaw(name=R_08, type=IsZero, indication=ForAll, prop=(1->Particle) |- ((2 * C_10[1]) + (-1 * (Partial[C_28]/Partial[posx[1]] * (C_06[1] ** -1)))) is zero, valid_experiments=['oscillation', 'collision', 'motiony', 'oscillationy', 'motion0', 'motion0y', 'motion0_3d', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'collision_nh', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'hanging_spring_1', 'hanging_spring_2', 'hanging_spring_3', 'pendulum_oscillation_1', 'pendulum_oscillation_2', 'projectile_oscillation_1', 'projectile_oscillation_2', 'oscillation_x_1', 'oscillation_x_2', 'oscillation_x_3', 'oscillation_2d_1', 'oscillation_2d_2', 'oscillation_2d_3', 'oscillation_r_3', 'oscillation_r_4', 'oscillation_rot_1', 'oscillation_rot_2', 'oscillation_rot_3', 'celestial_2_yz'], father=R_02)
# (1->Particle) |- ((2 * C_10[1]) + (-1 * (Partial[C_28]/Partial[posx[1]] * (C_06[1] ** -1)))) is zero
# (1->Particle) |- ((2 * D^2[posx[1]]/D[t[0]]^2) + (-1 * (Partial[C_28]/Partial[posx[1]] * (C_06[1] ** -1)))) is zero
# Not valid experiments: [celestial_3, slope_oscillation_1, stringmotion0, motion, celestial_4, slope_oscillation_2, celestial_2_xz, motion_3d, celestial_2_xy]

# %% [markdown]
# ### find dynamic: $\sum_{i\in\text{particles}}T_{y,i}$

# %%
debugger.work("collision_y", name_list=[mass, vy, t])
theorist.save_to_file("data/human/jds")
# Out:
# ########## collision_y ##########
#
#
# Process ID: 1943844 of experiment collision_y
# Selected concepts: ['t', 'C_06', 'C_07']
# Try to complete invalid general laws
# Finish trying to complete incomplete general laws
# Fixing general laws.
# Try to convert conserved general laws to zero ones
# Finish trying to convert conserved general laws to zero ones
# Found 51 relations
# Begin filtering relations
# After filtering, 9 relations left
# Propose new proposition: posx[2] is zero
# Propose new proposition: posz[2] is zero
# Propose new proposition: posz[1] is zero
# Propose new proposition: posx[1] is zero
# Propose new proposition: D[C_07[2]]/D[t[0]] is zero
# Propose new proposition: D[C_07[1]]/D[t[0]] is zero
# Propose new proposition: ((C_06[1] * C_07[1]) + (C_06[2] * C_07[2])) is conserved
# Propose new proposition: ((C_06[1] * (C_07[1] ** 2)) + (C_06[2] * (C_07[2] ** 2))) is conserved
# Propose new proposition: (((C_07[1] ** 2) / C_06[2]) + ((C_07[2] ** 2) / C_06[1])) is conserved
# Add to Specific model: 100%|██████████| 9/9 [00:00<00:00, 25.75it/s]
# Reducing 11 conclusions
# Reduce Conclusions:   0%|          | 0/11 [00:00<?, ?it/s]
# Insert to ideal: posx[1] is zero
# Reduce Conclusions:   9%|▉         | 1/11 [00:00<00:04,  2.33it/s]
# Insert to ideal: posx[2] is zero
# Reduce Conclusions:  18%|█▊        | 2/11 [00:00<00:03,  2.34it/s]
# Insert to ideal: posz[1] is zero
# Reduce Conclusions:  27%|██▋       | 3/11 [00:01<00:03,  2.27it/s]
# Insert to ideal: posz[2] is zero
# Reduce Conclusions:  36%|███▋      | 4/11 [00:02<00:03,  2.24it/s]
# Insert to ideal: D[C_07[2]]/D[t[0]] is zero
# Reduce Conclusions:  45%|████▌     | 5/11 [00:02<00:03,  1.85it/s]
# Insert to ideal: D[C_07[1]]/D[t[0]] is zero
# Reduce Conclusions:  55%|█████▍    | 6/11 [00:03<00:03,  1.39it/s]
# Insert to ideal: (dist[1, 2] - dist[2, 1]) is zero
# Reduce Conclusions:  64%|██████▎   | 7/11 [00:05<00:03,  1.19it/s]
# Insert to ideal: ((dist[1, 2] ** 2) - ((posy[1] - posy[2]) ** 2)) is zero
# Reduce Conclusions:  73%|███████▎  | 8/11 [00:06<00:02,  1.03it/s]
# Insert to ideal: ((C_06[1] * C_07[1]) + (C_06[2] * C_07[2])) is conserved
# Reduce Conclusions:  82%|████████▏ | 9/11 [00:07<00:02,  1.03s/it]
# Insert to ideal: ((C_06[1] * (C_07[1] ** 2)) + (C_06[2] * (C_07[2] ** 2))) is conserved
# Reduce Conclusions: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# calc_relations between  {'P10', 'C_06[2]', 'C_06[1]', 'P9'}
# Found 0 relations between conserved quantities
# Reducing 10 conclusions
# Reduce Conclusions:   0%|          | 0/10 [00:00<?, ?it/s]
# Insert to ideal: posx[1] is zero
# Reduce Conclusions:  10%|█         | 1/10 [00:00<00:03,  2.32it/s]
# Insert to ideal: posx[2] is zero
# Reduce Conclusions:  20%|██        | 2/10 [00:00<00:03,  2.32it/s]
# Insert to ideal: posz[1] is zero
# Reduce Conclusions:  30%|███       | 3/10 [00:01<00:03,  2.31it/s]
# Insert to ideal: posz[2] is zero
# Reduce Conclusions:  40%|████      | 4/10 [00:02<00:02,  2.29it/s]
# Insert to ideal: D[C_07[2]]/D[t[0]] is zero
# Reduce Conclusions:  50%|█████     | 5/10 [00:02<00:02,  1.83it/s]
# Insert to ideal: D[C_07[1]]/D[t[0]] is zero
# Reduce Conclusions:  60%|██████    | 6/10 [00:03<00:02,  1.40it/s]
# Insert to ideal: (dist[1, 2] - dist[2, 1]) is zero
# Reduce Conclusions:  70%|███████   | 7/10 [00:04<00:02,  1.21it/s]
# Insert to ideal: ((dist[1, 2] ** 2) - ((posy[1] - posy[2]) ** 2)) is zero
# Reduce Conclusions:  80%|████████  | 8/10 [00:06<00:01,  1.09it/s]
# Insert to ideal: ((C_06[1] * C_07[1]) + (C_06[2] * C_07[2])) is conserved
# Reduce Conclusions: 100%|██████████| 10/10 [00:07<00:00,  1.39it/s]
# Insert to ideal: ((C_06[1] * (C_07[1] ** 2)) + (C_06[2] * (C_07[2] ** 2))) is conserved
# Possible general law: (1->Particle) |- D[C_07[1]]/D[t[0]] is IsZero. Register it as both concept and law.
# Trivial or existing general law. Skip.
# Possible general law: [Sum:Particle] (1->Particle) |- (C_06[1] * C_07[1]) is IsConserved. Register it as both concept and law.
# Registered New Concept: C_30 = [Sum:Particle] (1->Particle) |- (C_06[1] * C_07[1])
# Registered new general law: R_09 = GeneralLaw(name=R_09, type=IsConserved, indication=Sum, prop=|- C_30 is conserved, valid_experiments=['collision_y', 'motion', 'collision', 'oscillation', 'stringmotion0', 'motion0', 'motion0y', 'motion0_3d', 'collision_elastic_3body', 'collision_2d', 'collision_nh', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'hanging_spring_1', 'hanging_spring_2', 'hanging_spring_3', 'pendulum_oscillation_1', 'pendulum_oscillation_2', 'projectile_oscillation_1', 'projectile_oscillation_2', 'oscillation_x_1', 'oscillation_x_2', 'oscillation_x_3', 'oscillation_2d_1', 'oscillation_2d_2', 'oscillation_2d_3', 'oscillation_r_3', 'oscillation_r_4', 'celestial_2_xy', 'celestial_2_xz', 'celestial_2_yz', 'celestial_3', 'celestial_4'], father=None)
# Possible general law: [Sum:Particle] (1->Particle) |- (C_06[1] * (C_07[1] ** 2)) is IsConserved. Register it as both concept and law.
# Registered New Concept: C_31 = [Sum:Particle] (1->Particle) |- (C_06[1] * (C_07[1] ** 2))
# Registered new general law: R_10 = GeneralLaw(name=R_10, type=IsConserved, indication=Sum, prop=|- C_31 is conserved, valid_experiments=['collision_y', 'motion', 'collision', 'oscillation', 'stringmotion0', 'motion0', 'motion0y', 'motion0_3d', 'collision_elastic_3body', 'collision_2d', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'hanging_spring_1', 'hanging_spring_2', 'hanging_spring_3', 'pendulum_oscillation_1', 'pendulum_oscillation_2', 'oscillation_x_1', 'oscillation_x_2', 'oscillation_x_3', 'celestial_2_xz'], father=None)
# Possible general law: (1->Particle) |- D[C_07[1]]/D[t[0]] is IsZero. Register it as both concept and law.
# Trivial or existing general law. Skip.
# Fixing general laws.
# Registered New Concept: C_35 = (1->Particle) |- (C_06[1] * C_07[1])
# Registered New Concept: C_37 = (1->Particle) |- (C_06[1] * (C_07[1] ** 2))
# Try to reduce R_09
# --- R_09 is marked as useful
# Update diffalg for existing marked general laws
# Check if R_01 should be removed
# Finish updating diffalg
# Try to reduce R_10
# --- R_10 is marked as useful
# Update diffalg for existing marked general laws
# Finish updating diffalg
# Total rewards: 6
# Saving knowledge to data/human/jds_knowledge.txt

# %%
py = debugger.check_concept_discovered(mass*vy, "py")
ty = debugger.check_concept_discovered(mass*vy**2, "ty")
sum_py = debugger.check_concept_discovered(py.mksum('Particle'), "sum_py")
sum_ty = debugger.check_concept_discovered(ty.mksum('Particle'), "sum_ty")
py, ty, sum_py, sum_ty
# Out:
# (C_35, C_37, C_30, C_31)

# %% [markdown]
# ### find universal constant: $g$

# %%
debugger.work("projectile", name_list=[az, posx, posz])
theorist.save_to_file("data/human/jds")
# Out:
# ########## projectile ##########
#
#
# Process ID: 1943844 of experiment projectile
# Selected concepts: ['C_16', 'posz', 'posx']
# Try to complete invalid general laws
# Finish trying to complete incomplete general laws
# Fixing general laws.
# Try to convert conserved general laws to zero ones
# Finish trying to convert conserved general laws to zero ones
# Found 19 relations
# Begin filtering relations
# After filtering, 3 relations left
# Propose new proposition: D[posx[1]]/D[t[0]] is conserved
# Propose new proposition: C_16[1] is conserved
# Propose new proposition: ((C_16[1] * posz[1]) / posz[1]) is conserved
# Add to Specific model: 100%|██████████| 3/3 [00:00<00:00,  9.12it/s]
# Reducing 2 conclusions
# Reduce Conclusions:   0%|          | 0/2 [00:00<?, ?it/s]
# Insert to ideal: D[posx[1]]/D[t[0]] is conserved
# Reduce Conclusions: 100%|██████████| 2/2 [00:00<00:00,  2.02it/s]
# Insert to ideal: C_16[1] is conserved
# calc_relations between  {'C_06[1]', 'P1'}
# Found 0 relations between conserved quantities
# Reducing 2 conclusions
# Reduce Conclusions:   0%|          | 0/2 [00:00<?, ?it/s]
# Insert to ideal: D[posx[1]]/D[t[0]] is conserved
# Reduce Conclusions: 100%|██████████| 2/2 [00:01<00:00,  1.95it/s]
# Insert to ideal: C_16[1] is conserved
# Possible general law: (1->Particle) |- C_16[1] is IsConserved. Register it as both concept and law.
# Trivial or existing general law. Skip.
# Fixing general laws.
# Registered New Universal Constant: C_44 = ExpData.ConstData =
# mean = -9.80123416277668, std = 0.000012720917695070272 defined by [#projectile |- C_16[1]]
# Total rewards: 2
# Saving knowledge to data/human/jds_knowledge.txt

# %%
g = debugger.check_concept_discovered(Intrinsic(f"[#projectile (1->Particle) |- -{az(1)}]"), "g")
g
# Out:
# -C_44

# %% [markdown]
# ### find dynamic: $v_z^2+2gz$ of a particle

# %%
debugger.work("oblique_projectile", name_list=[posz, vz, g])
theorist.save_to_file("data/human/jds")
# Out:
# ########## oblique_projectile ##########
#
#
# Process ID: 1943844 of experiment oblique_projectile
# Selected concepts: ['C_44', 'C_14', 'posz']
# Try to complete invalid general laws
# Finish trying to complete incomplete general laws
# Fixing general laws.
# Try to convert conserved general laws to zero ones
# Finish trying to convert conserved general laws to zero ones
# Found 20 relations
# Begin filtering relations
# After filtering, 2 relations left
# Propose new proposition: D[(C_14[1] * C_14[1])]/D[posz[1]] is conserved
# Propose new proposition: ((C_14[1] * C_14[1]) - (2 * (C_44 * posz[1]))) is conserved
# Add to Specific model: 100%|██████████| 2/2 [00:00<00:00,  4.60it/s]
# Reducing 2 conclusions
# Reduce Conclusions:   0%|          | 0/2 [00:00<?, ?it/s]
# Insert to ideal: D[(C_14[1] * C_14[1])]/D[posz[1]] is conserved
# Reduce Conclusions: 100%|██████████| 2/2 [00:01<00:00,  1.91it/s]
# Insert to ideal: ((C_14[1] * C_14[1]) - (2 * (C_44 * posz[1]))) is conserved
# calc_relations between  {'C_06[1]', 'P2'}
# Found 0 relations between conserved quantities
# Reducing 2 conclusions
# Reduce Conclusions:   0%|          | 0/2 [00:00<?, ?it/s]
# Insert to ideal: D[(C_14[1] * C_14[1])]/D[posz[1]] is conserved
# Reduce Conclusions: 100%|██████████| 2/2 [00:01<00:00,  1.96it/s]
# Insert to ideal: ((C_14[1] * C_14[1]) - (2 * (C_44 * posz[1]))) is conserved
# Possible general law: (1->Particle) |- ((C_14[1] * C_14[1]) - (2 * (C_44 * posz[1]))) is IsConserved. Register it as both concept and law.
# Registered New Concept: C_46 = (1->Particle) |- ((C_14[1] * C_14[1]) - (2 * (C_44 * posz[1])))
# Registered new general law: R_11 = GeneralLaw(name=R_11, type=IsConserved, indication=ForAll, prop=(1->Particle) |- C_46[1] is conserved, valid_experiments=['oblique_projectile', 'collision', 'oscillation', 'oscillationy', 'motion0', 'motion0y', 'motion0_3d', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'collision_nh', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'vertical_projectile', 'oscillation_x_1', 'oscillation_x_2', 'oscillation_x_3', 'oscillation_2d_1', 'oscillation_2d_2', 'oscillation_2d_3', 'oscillation_r_3', 'oscillation_r_4', 'oscillation_rot_1', 'oscillation_rot_2', 'oscillation_rot_3', 'celestial_2_xy', 'celestial_3', 'celestial_4'], father=None)
# Possible general law: (1->Particle) |- D[(C_14[1] * C_14[1])]/D[posz[1]] is IsConserved. Register it as both concept and law.
# Registered New Concept: C_47 = (1->Particle) |- D[(C_14[1] * C_14[1])]/D[posz[1]]
# Registered new general law: R_12 = GeneralLaw(name=R_12, type=IsConserved, indication=ForAll, prop=(1->Particle) |- C_47[1] is conserved, valid_experiments=['oblique_projectile', 'motion', 'collision', 'oscillation', 'motiony', 'oscillationy', 'motion0', 'motion0y', 'motion0_3d', 'motion_3d', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'collision_nh', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'vertical_projectile', 'oscillation_x_1', 'oscillation_x_2', 'oscillation_x_3', 'oscillation_2d_1', 'oscillation_2d_2', 'oscillation_2d_3', 'oscillation_r_3', 'oscillation_r_4', 'oscillation_rot_1', 'oscillation_rot_2', 'oscillation_rot_3', 'celestial_2_xy', 'celestial_3', 'celestial_4'], father=None)
# Fixing general laws.
# Try to reduce R_12
# --- R_12 is marked as useful
# Update diffalg for existing marked general laws
# Finish updating diffalg
# Try to reduce R_11
# --- R_11 is marked as useful
# Update diffalg for existing marked general laws
# Finish updating diffalg
# Total rewards: 4
# Saving knowledge to data/human/jds_knowledge.txt

# %%
vzsq_plus_2gz = debugger.check_concept_discovered(vz ** 2 + 2 * g * posz, "vzsq_plus_2gz")
vzsq_plus_2gz
# Out:
# C_46

# %% [markdown]
# ### find dynamic: $\sum_{i\in\text{particles}}T_{z,i}$
# ### find general conclusion: $\sum_{i\in\text{particles}}T_{x,i} + \sum_{i\in\text{particles}}T_{y,i} + \sum_{i\in\text{particles}}T_{z,i} = 0$

# %%
debugger.work("collision_nh", name_list=[sum_ty, t])
theorist.save_to_file("data/human/jds")
# Out:
# ########## collision_nh ##########
#
#
# Process ID: 1943844 of experiment collision_nh
# Selected concepts: ['t', 'C_31']
# Try to complete invalid general laws
# - Try to complete R_05
# Registered new general law: R_13 = GeneralLaw(name=R_13, type=IsConserved, indication=Sum, prop=|- (C_20 + C_31) is conserved, valid_experiments=['collision_nh'], father=R_05)
# - Try to complete R_07
# Registered new general law: R_14 = GeneralLaw(name=R_14, type=IsConserved, indication=Sum, prop=|- (C_31 + (C_20 + (-1 * C_28))) is conserved, valid_experiments=['collision_nh'], father=R_07)
# - Try to complete R_10
# Finish trying to complete incomplete general laws
# Fixing general laws.
# Try to convert conserved general laws to zero ones
# Finish trying to convert conserved general laws to zero ones
# Found 10 relations
# Begin filtering relations
# After filtering, 4 relations left
# Propose new proposition: posz[1] is zero
# Propose new proposition: posz[2] is zero
# Propose new proposition: (((dist[1, 2] ** 2) - ((posx[1] - posx[2]) ** 2)) - ((posy[1] - posy[2]) ** 2)) is zero
# Propose new proposition: D[C_31]/D[t[0]] is zero
# Add to Specific model: 100%|██████████| 4/4 [00:00<00:00, 105.43it/s]
# Reducing 5 conclusions
# Reduce Conclusions:   0%|          | 0/5 [00:00<?, ?it/s]
# Insert to ideal: posz[1] is zero
# Reduce Conclusions:  20%|██        | 1/5 [00:00<00:01,  2.29it/s]
# Insert to ideal: posz[2] is zero
# Reduce Conclusions:  40%|████      | 2/5 [00:00<00:01,  2.29it/s]
# Insert to ideal: (dist[1, 2] - dist[2, 1]) is zero
# Reduce Conclusions:  60%|██████    | 3/5 [00:01<00:00,  2.31it/s]
# Insert to ideal: (((dist[1, 2] ** 2) - ((posx[1] - posx[2]) ** 2)) - ((posy[1] - posy[2]) ** 2)) is zero
# Reduce Conclusions: 100%|██████████| 5/5 [00:04<00:00,  1.04it/s]
# Insert to ideal: D[C_31]/D[t[0]] is zero
# calc_relations between  {'C_06[1]', 'C_06[2]'}
# Found 0 relations between conserved quantities
# Reducing 5 conclusions
# Reduce Conclusions:   0%|          | 0/5 [00:00<?, ?it/s]
# Insert to ideal: posz[1] is zero
# Reduce Conclusions:  20%|██        | 1/5 [00:00<00:01,  2.27it/s]
# Insert to ideal: posz[2] is zero
# Reduce Conclusions:  40%|████      | 2/5 [00:00<00:01,  2.32it/s]
# Insert to ideal: (dist[1, 2] - dist[2, 1]) is zero
# Reduce Conclusions:  60%|██████    | 3/5 [00:01<00:00,  2.30it/s]
# Insert to ideal: (((dist[1, 2] ** 2) - ((posx[1] - posx[2]) ** 2)) - ((posy[1] - posy[2]) ** 2)) is zero
# Reduce Conclusions: 100%|██████████| 5/5 [00:04<00:00,  1.07it/s]
# Insert to ideal: D[C_31]/D[t[0]] is zero
# Fixing general laws.
# Registered New Concept: C_52 = [Sum:Particle] (1->Particle) |- (C_06[1] * (C_14[1] ** 2))
# Registered new general law: R_15 = GeneralLaw(name=R_15, type=IsConserved, indication=Sum, prop=|- (C_52 + (C_20 + C_31)) is conserved, valid_experiments=['collision_nh'], father=None)
# Try to reduce R_14
# --- R_14 is marked as useful
# Update diffalg for existing marked general laws
# Finish updating diffalg
# Try to reduce R_13
# --- R_13 is marked as useful
# Update diffalg for existing marked general laws
# Finish updating diffalg
# Try to reduce R_15
# --- R_15 is marked as useful
# Update diffalg for existing marked general laws
# Finish updating diffalg
# Total rewards: 4
# Saving knowledge to data/human/jds_knowledge.txt

# %% [markdown]
# ### find general conclusion: $\sum_{i\in\text{particles}}T_{x,i}+\sum_{i\in\text{particles}}T_{y,i}+\sum_{i\in\text{particles}}T_{z,i}+2\sum_{i\in\text{particles}}gz+\sum_{i\in\text{springs}}V^{(\text{spring})}_{i}=\text{const.}$

# %% [markdown]
# ### find general conclusion: $\forall i\in\text{particles},\,a_{z,i}+\frac{1}{m_i}\frac{\partial \sum_{j\in\text{springs}}V^{(\text{spring})}_{j}}{\partial z_i}=\text{const.}$
#
# (Newton's second law in $z$ direction is now completed)

# %%
debugger.work("hanging_spring_1", name_list=[vzsq_plus_2gz, sum_vspring])
theorist.save_to_file("data/human/jds")
# Out:
# ########## hanging_spring_1 ##########
#
#
# Process ID: 1943844 of experiment hanging_spring_1
# Selected concepts: ['C_46', 'C_28']
# Try to complete invalid general laws
# - Try to complete R_03
# Registered new general law: R_16 = GeneralLaw(name=R_16, type=IsConserved, indication=ForAll, prop=(1->Particle) |- ((2 * C_16[1]) + (-1 * (Partial[C_28]/Partial[posz[1]] * (C_06[1] ** -1)))) is conserved, valid_experiments=['hanging_spring_1'], father=R_03)
# - Try to complete R_07
# Registered New Concept: C_53 = [Sum:Particle] (1->Particle) |- (C_06[1] * C_46[1])
# Registered new general law: R_17 = GeneralLaw(name=R_17, type=IsConserved, indication=Sum, prop=|- (C_53 + (C_20 + (-1 * C_28))) is conserved, valid_experiments=['hanging_spring_1'], father=R_07)
# - Try to complete R_11
# - Try to complete R_12
# - Try to complete R_14
# Registered new general law: R_19 = GeneralLaw(name=R_19, type=IsConserved, indication=Sum, prop=|- (C_53 + (C_31 + (C_20 + (-1 * C_28)))) is conserved, valid_experiments=['hanging_spring_1'], father=R_14)
# - Try to complete R_15
# Finish trying to complete incomplete general laws
# Fixing general laws.
# Try to complete invalid general laws again
# - Try to complete R_11
# - Try to complete R_12
# - Try to complete R_15
# Finish trying to complete incomplete general laws
# Fixing general laws.
# Try to convert conserved general laws to zero ones
# Finish trying to convert conserved general laws to zero ones
# Found 2 relations
# Begin filtering relations
# After filtering, 3 relations left
# Propose new proposition: posy[1] is zero
# Propose new proposition: posx[1] is zero
# Propose new proposition: (posz[1] + length[2]) is conserved
# Add to Specific model: 100%|██████████| 3/3 [00:00<00:00, 13148.29it/s]
# Reducing 3 conclusions
# Reduce Conclusions:   0%|          | 0/3 [00:00<?, ?it/s]
# Insert to ideal: posx[1] is zero
# Reduce Conclusions:  33%|███▎      | 1/3 [00:00<00:00,  2.62it/s]
# Insert to ideal: posy[1] is zero
# Reduce Conclusions: 100%|██████████| 3/3 [00:00<00:00,  3.61it/s]
# Insert to ideal: (posz[1] + length[2]) is conserved
# calc_relations between  {'C_01[2]', 'P1', 'C_06[1]', 'C_27[2]'}
# Found 0 relations between conserved quantities
# Reducing 3 conclusions
# Reduce Conclusions:   0%|          | 0/3 [00:00<?, ?it/s]
# Insert to ideal: posx[1] is zero
# Reduce Conclusions:  33%|███▎      | 1/3 [00:00<00:00,  2.84it/s]
# Insert to ideal: posy[1] is zero
# Reduce Conclusions: 100%|██████████| 3/3 [00:00<00:00,  3.68it/s]
# Insert to ideal: (posz[1] + length[2]) is conserved
# Fixing general laws.
# Try to reduce R_19
# --- R_19 is marked as useful
# Update diffalg for existing marked general laws
# Check if R_15 should be removed
# Check if R_13 should be removed
# Check if R_14 should be removed
# --- R_14 is a subexpr of R_19
# --- R_14 is removed
# Finish updating diffalg
# Try to reduce R_17
# --- R_17 is a subexpr of some marked general laws in {'R_10', 'R_19', 'R_09'}
# Try to reduce R_16
# --- R_16 is marked as useful
# Update diffalg for existing marked general laws
# Check if R_11 should be removed
# Check if R_12 should be removed
# Check if R_03 should be removed
# Finish updating diffalg
# Total rewards: 3
# Saving knowledge to data/human/jds_knowledge.txt

# %%
tz_2mgz = debugger.check_concept_discovered((mass*vzsq_plus_2gz).mksum('Particle'), "tz_2mgz")
tz_2mgz
# Out:
# C_53

# %%
temp_expr = 2 * az(1) + Exp.Partial(sum_vspring(), posz(1).unwrap_atom) / mass(1)
print(temp_expr)
prop_az_partvk = debugger.check_law(f"(1->Particle) |- {temp_expr} is conserved")
prop_az_partvk
# Out:
# ((2 * C_16[1]) + (Partial[(-C_28)]/Partial[posz[1]] / C_06[1]))
# 'R_16'

# %% [markdown]
# inspect which experiments are now not covered by Newton's second law in $z$ direction

# %%
print(debugger.law_info(prop_az_partvk))
# Out:
# GeneralLaw(name=R_16, type=IsConserved, indication=ForAll, prop=(1->Particle) |- ((2 * C_16[1]) + (-1 * (Partial[C_28]/Partial[posz[1]] * (C_06[1] ** -1)))) is conserved, valid_experiments=['hanging_spring_1', 'motion', 'collision', 'oscillation', 'motiony', 'oscillationy', 'motion0', 'motion0y', 'motion0_3d', 'motion_3d', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'collision_nh', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'hanging_spring_2', 'hanging_spring_3', 'pendulum_oscillation_1', 'pendulum_oscillation_2', 'slope_oscillation_1', 'slope_oscillation_2', 'projectile_oscillation_1', 'projectile_oscillation_2', 'oscillation_x_1', 'oscillation_x_2', 'oscillation_x_3', 'oscillation_2d_1', 'oscillation_2d_2', 'oscillation_2d_3', 'oscillation_r_3', 'oscillation_r_4', 'oscillation_rot_1', 'oscillation_rot_2', 'oscillation_rot_3', 'celestial_2_xy', 'celestial_3', 'celestial_4'], father=R_03)
# (1->Particle) |- ((2 * C_16[1]) + (-1 * (Partial[C_28]/Partial[posz[1]] * (C_06[1] ** -1)))) is conserved
# (1->Particle) |- ((2 * D^2[posz[1]]/D[t[0]]^2) + (-1 * (Partial[C_28]/Partial[posz[1]] * (C_06[1] ** -1)))) is conserved
# Not valid experiments: [celestial_2_yz, celestial_2_xz, stringmotion0]

# %% [markdown]
# validate the general conclusion of energy conservation

# %%
prop_tx_ty_tz_2mgz_vk = debugger.check_law((sum_tx + sum_ty + tz_2mgz + sum_vspring).gen_prop("Conserved"))
prop_tx_ty_tz_2mgz_vk
# Out:
# 'R_19'

# %%
debugger.sympy_raw_definition((sum_tx+ sum_ty + tz_2mgz + sum_vspring)(), "hanging_spring_1")
# Out:
# C_06_1*(-2*C_44*posz_1(t_0) + Derivative(posz_1(t_0), t_0)**2) + C_06_1*Derivative(posx_1(t_0), t_0)**2 + C_06_1*Derivative(posy_1(t_0), t_0)**2 - C_27_2*(-C_01_2 + length_2(t_0))**2

# %% [markdown]
# inspect which experiments are now not covered by energy conservation now

# %%
print(debugger.law_info(prop_tx_ty_tz_2mgz_vk))
# Out:
# GeneralLaw(name=R_19, type=IsConserved, indication=Sum, prop=|- (C_53 + (C_31 + (C_20 + (-1 * C_28)))) is conserved, valid_experiments=['hanging_spring_1', 'motion', 'collision', 'oscillation', 'motiony', 'oscillationy', 'stringmotion0', 'motion0', 'motion0y', 'motion0_3d', 'motion_3d', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'collision_nh', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'hanging_spring_2', 'hanging_spring_3', 'pendulum_oscillation_1', 'pendulum_oscillation_2', 'slope_oscillation_1', 'slope_oscillation_2', 'projectile_oscillation_1', 'projectile_oscillation_2', 'oscillation_x_1', 'oscillation_x_2', 'oscillation_x_3', 'oscillation_2d_1', 'oscillation_2d_2', 'oscillation_2d_3', 'oscillation_r_3', 'oscillation_r_4', 'oscillation_rot_1', 'oscillation_rot_2', 'oscillation_rot_3'], father=None)
# |- (C_53 + (C_31 + (C_20 + (-1 * C_28)))) is conserved
# |- (C_53 + (C_31 + (C_20 + (-1 * C_28)))) is conserved
# Not valid experiments: [celestial_2_yz, celestial_3, celestial_4, celestial_2_xz, celestial_2_xy]

# %% [markdown]
# ### Convert $a_z = \text{const.}\, \text{to}\, a_z = 0.$

# %%
debugger.work("free_fall", name_list=[vzsq_plus_2gz, posx, posy])
theorist.save_to_file("data/human/jds")
# Out:
# ########## free_fall ##########
#
#
# Process ID: 1943844 of experiment free_fall
# Selected concepts: ['C_46']
# Try to complete invalid general laws
# - Try to complete R_15
# Finish trying to complete incomplete general laws
# Fixing general laws.
# Try to convert conserved general laws to zero ones
# Registered new general law: R_21 = GeneralLaw(name=R_21, type=IsZero, indication=ForAll, prop=(1->Particle) |- (Partial[C_46[1]]/Partial[posz[1]] + ((2 * C_16[1]) + (-1 * (Partial[C_28]/Partial[posz[1]] * (C_06[1] ** -1))))) is zero, valid_experiments=['hanging_spring_1', 'motion', 'collision', 'oscillation', 'motiony', 'oscillationy', 'motion0', 'motion0y', 'motion0_3d', 'motion_3d', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'collision_nh', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'hanging_spring_2', 'hanging_spring_3', 'pendulum_oscillation_1', 'pendulum_oscillation_2', 'slope_oscillation_1', 'slope_oscillation_2', 'projectile_oscillation_1', 'projectile_oscillation_2', 'oscillation_x_1', 'oscillation_x_2', 'oscillation_x_3', 'oscillation_2d_1', 'oscillation_2d_2', 'oscillation_2d_3', 'oscillation_r_3', 'oscillation_r_4', 'oscillation_rot_1', 'oscillation_rot_2', 'oscillation_rot_3', 'celestial_2_xy', 'celestial_3', 'celestial_4'], father=R_03)
# Finish trying to convert conserved general laws to zero ones
# Found 1 relations
# Begin filtering relations
# After filtering, 3 relations left
# Propose new proposition: posy[1] is zero
# Propose new proposition: posx[1] is zero
# Propose new proposition: C_46[1] is conserved
# Add to Specific model: 100%|██████████| 3/3 [00:00<00:00, 14.55it/s]
# Reducing 3 conclusions
# Reduce Conclusions:   0%|          | 0/3 [00:00<?, ?it/s]
# Insert to ideal: posx[1] is zero
# Reduce Conclusions:  33%|███▎      | 1/3 [00:00<00:00,  2.56it/s]
# Insert to ideal: posy[1] is zero
# Reduce Conclusions: 100%|██████████| 3/3 [00:01<00:00,  2.70it/s]
# Insert to ideal: C_46[1] is conserved
# calc_relations between  {'P3', 'C_06[1]'}
# Found 0 relations between conserved quantities
# Reducing 3 conclusions
# Reduce Conclusions:   0%|          | 0/3 [00:00<?, ?it/s]
# Insert to ideal: posx[1] is zero
# Reduce Conclusions:  33%|███▎      | 1/3 [00:00<00:00,  2.57it/s]
# Insert to ideal: posy[1] is zero
# Reduce Conclusions: 100%|██████████| 3/3 [00:01<00:00,  2.70it/s]
# Insert to ideal: C_46[1] is conserved
# Possible general law: (1->Particle) |- C_46[1] is IsConserved. Register it as both concept and law.
# Trivial or existing general law. Skip.
# Fixing general laws.
# Try to reduce R_21
# --- R_21 is marked as useful
# Update diffalg for existing marked general laws
# Check if R_11 should be removed
# Check if R_12 should be removed
# Check if R_03 should be removed
# Finish updating diffalg
# Total rewards: 2
# Saving knowledge to data/human/jds_knowledge.txt

# %%
temp_expr = 2 * az(1) + Exp.Partial(sum_vspring(), posz(1).unwrap_atom) / mass(1) + Exp.Partial(vzsq_plus_2gz(1), posz(1).unwrap_atom)
print(temp_expr)
prop_az_partvk_gz = debugger.check_law(f"(1->Particle) |- {temp_expr} is zero")
prop_az_partvk_gz
# Out:
# (Partial[C_46[1]]/Partial[posz[1]] + ((2 * C_16[1]) + (Partial[(-C_28)]/Partial[posz[1]] / C_06[1])))
# 'R_21'

# %% [markdown]
# inspect which experiments are now not covered by Newton's second law in $z$ direction now

# %%
print(debugger.law_info(prop_az_partvk_gz))
# Out:
# GeneralLaw(name=R_21, type=IsZero, indication=ForAll, prop=(1->Particle) |- (Partial[C_46[1]]/Partial[posz[1]] + ((2 * C_16[1]) + (-1 * (Partial[C_28]/Partial[posz[1]] * (C_06[1] ** -1))))) is zero, valid_experiments=['hanging_spring_1', 'motion', 'collision', 'oscillation', 'motiony', 'oscillationy', 'motion0', 'motion0y', 'motion0_3d', 'motion_3d', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'collision_nh', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'hanging_spring_2', 'hanging_spring_3', 'pendulum_oscillation_1', 'pendulum_oscillation_2', 'slope_oscillation_1', 'slope_oscillation_2', 'projectile_oscillation_1', 'projectile_oscillation_2', 'oscillation_x_1', 'oscillation_x_2', 'oscillation_x_3', 'oscillation_2d_1', 'oscillation_2d_2', 'oscillation_2d_3', 'oscillation_r_3', 'oscillation_r_4', 'oscillation_rot_1', 'oscillation_rot_2', 'oscillation_rot_3', 'celestial_2_xy', 'celestial_3', 'celestial_4'], father=R_03)
# (1->Particle) |- (Partial[C_46[1]]/Partial[posz[1]] + ((2 * C_16[1]) + (-1 * (Partial[C_28]/Partial[posz[1]] * (C_06[1] ** -1))))) is zero
# (1->Particle) |- (((2 * D^2[posz[1]]/D[t[0]]^2) + (-1 * (Partial[C_28]/Partial[posz[1]] * (C_06[1] ** -1)))) + Partial[((D[posz[1]]/D[t[0]] * D[posz[1]]/D[t[0]]) - (2 * (C_44 * posz[1])))]/Partial[posz[1]]) is zero
# Not valid experiments: [celestial_2_yz, celestial_2_xz, stringmotion0]

# %% [markdown]
# ### find general conclusion: $\sum_{i\in\text{particles}}T_{x,i}+\sum_{i\in\text{particles}}T_{y,i}+\sum_{i\in\text{particles}}T_{z,i}+2\sum_{i\in\text{particles}}gz+\sum_{i\in\text{springs}}V^{(\text{spring})}_{i} + \sum_{i,j\in\text{particles}}Gm_im_j/r_{ij}=\text{const.}$
#
# ### find general conclusion: $\forall i\in\text{particles},\,a_{x,i}+\frac{1}{m_i}\frac{\partial \sum_{j\in\text{springs}}V^{(\text{spring})}_{j}}{\partial x_i} + F_{G,x}=0.$
#
# ### find general conclusion: $\forall i\in\text{particles},\,a_{y,i}+F_{G,y}=0.$

# %%
debugger.work("celestial_2_xy", name_list=[vx, dist, t])
# Out:
# ########## celestial_2_xy ##########
#
#
# Process ID: 1943844 of experiment celestial_2_xy
# Selected concepts: ['t', 'C_09', 'dist']
# Try to complete invalid general laws
# - Try to complete R_01
# - Try to complete R_02
# - Try to complete R_05
# - Try to complete R_07
# - Try to complete R_08
# - Try to complete R_10
# - Try to complete R_13
# Registered New Universal Constant: C_59 = ExpData.ConstData =
# mean = 0.0000000000538711530446328, std = 0.000000000000017520134122469212 defined by [#celestial_2_xy |- (D[(C_20 + C_31)]/D[((dist[1, 2] ** -1) + (dist[2, 1] ** -1))] / (C_06[1] * C_06[2]))]
# Registered New Concept: C_60 = [Sum:Particle] (1->Particle) (2->Particle) |- ((dist[1, 2] ** -1) * (C_59 * (C_06[2] * C_06[1])))
# Registered new general law: R_23 = GeneralLaw(name=R_23, type=IsConserved, indication=Sum, prop=|- ((C_20 + C_31) + (-1 * C_60)) is conserved, valid_experiments=['celestial_2_xy'], father=R_13)
# - Try to complete R_15
# - Try to complete R_19
# Finish trying to complete incomplete general laws
# Fixing general laws.
# Try to complete invalid general laws again
# - Try to complete R_01
# Registered new general law: R_24 = GeneralLaw(name=R_24, type=IsZero, indication=ForAll, prop=(1->Particle) |- ((2 * C_08[1]) + (-1 * (Partial[C_60]/Partial[posy[1]] * (C_06[1] ** -1)))) is zero, valid_experiments=['celestial_2_xy'], father=R_01)
# - Try to complete R_02
# Registered new general law: R_25 = GeneralLaw(name=R_25, type=IsZero, indication=ForAll, prop=(1->Particle) |- ((2 * C_10[1]) + (-1 * (Partial[C_60]/Partial[posx[1]] * (C_06[1] ** -1)))) is zero, valid_experiments=['celestial_2_xy'], father=R_02)
# - Try to complete R_05
# - Try to complete R_07
# - Try to complete R_08
# Registered new general law: R_26 = GeneralLaw(name=R_26, type=IsZero, indication=ForAll, prop=(1->Particle) |- ((-1 * (Partial[C_60]/Partial[posx[1]] * (C_06[1] ** -1))) + ((2 * C_10[1]) + (-1 * (Partial[C_28]/Partial[posx[1]] * (C_06[1] ** -1))))) is zero, valid_experiments=['celestial_2_xy'], father=R_08)
# - Try to complete R_10
# - Try to complete R_15
# Registered new general law: R_27 = GeneralLaw(name=R_27, type=IsConserved, indication=Sum, prop=|- ((-1 * C_60) + (C_52 + (C_20 + C_31))) is conserved, valid_experiments=['celestial_2_xy'], father=R_15)
# - Try to complete R_19
# Registered new general law: R_28 = GeneralLaw(name=R_28, type=IsConserved, indication=Sum, prop=|- ((-1 * C_60) + (C_53 + (C_31 + (C_20 + (-1 * C_28))))) is conserved, valid_experiments=['celestial_2_xy'], father=R_19)
# Finish trying to complete incomplete general laws
# Fixing general laws.
# Try to convert conserved general laws to zero ones
# Finish trying to convert conserved general laws to zero ones
# Found 118 relations
# Begin filtering relations
# After filtering, 4 relations left
# Propose new proposition: posz[1] is zero
# Propose new proposition: posz[2] is zero
# Propose new proposition: D[C_09[1]]/D[C_09[2]] is conserved
# Propose new proposition: (((dist[1, 2] ** 2) - ((posx[1] - posx[2]) ** 2)) - ((posy[1] - posy[2]) ** 2)) is zero
# Add to Specific model: 100%|██████████| 4/4 [00:37<00:00,  9.42s/it]
# Reducing 5 conclusions
# Reduce Conclusions:   0%|          | 0/5 [00:00<?, ?it/s]
# Insert to ideal: posz[1] is zero
# Reduce Conclusions:  20%|██        | 1/5 [00:00<00:01,  2.85it/s]
# Insert to ideal: posz[2] is zero
# Reduce Conclusions:  40%|████      | 2/5 [00:00<00:01,  2.66it/s]
# Insert to ideal: (dist[1, 2] - dist[2, 1]) is zero
# Reduce Conclusions:  60%|██████    | 3/5 [00:01<00:00,  2.59it/s]
# Insert to ideal: D[C_09[1]]/D[C_09[2]] is conserved
# Reduce Conclusions: 100%|██████████| 5/5 [00:02<00:00,  2.23it/s]
# Insert to ideal: (((dist[1, 2] ** 2) - ((posx[1] - posx[2]) ** 2)) - ((posy[1] - posy[2]) ** 2)) is zero
# calc_relations between  {'P5', 'C_06[1]', 'C_06[2]'}
# Found 2 relations between conserved quantities
# Reducing 5 conclusions
# Reduce Conclusions:   0%|          | 0/5 [00:00<?, ?it/s]
# Insert to ideal: posz[1] is zero
# Reduce Conclusions:  20%|██        | 1/5 [00:00<00:01,  2.70it/s]
# Insert to ideal: posz[2] is zero
# Reduce Conclusions:  40%|████      | 2/5 [00:00<00:01,  2.55it/s]
# Insert to ideal: (dist[1, 2] - dist[2, 1]) is zero
# Reduce Conclusions:  60%|██████    | 3/5 [00:01<00:00,  2.54it/s]
# Insert to ideal: D[C_09[1]]/D[C_09[2]] is conserved
# Reduce Conclusions: 100%|██████████| 5/5 [00:02<00:00,  2.20it/s]
# Insert to ideal: (((dist[1, 2] ** 2) - ((posx[1] - posx[2]) ** 2)) - ((posy[1] - posy[2]) ** 2)) is zero
# Fixing general laws.
# Registered New Concept: C_63 = (1->Particle) (2->Particle) |- D[C_09[1]]/D[C_09[2]]
# Try to reduce R_24
# --- R_24 is marked as useful
# Update diffalg for existing marked general laws
# Check if R_01 should be removed
# Finish updating diffalg
# Try to reduce R_26
# --- R_26 is marked as useful
# Update diffalg for existing marked general laws
# Finish updating diffalg
# Try to reduce R_27
# --- R_27 is marked as useful
# Update diffalg for existing marked general laws
# Check if R_15 should be removed
# Finish updating diffalg
# Try to reduce R_25
# --- R_25 is a subexpr of some marked general laws in {'R_06', 'R_26'}
# Try to reduce R_28
# --- R_28 is marked as useful
# Update diffalg for existing marked general laws
# Check if R_19 should be removed
# Check if R_11 should be removed
# Check if R_12 should be removed
# Check if R_15 should be removed
# Check if R_13 should be removed
# Check if R_03 should be removed
# Check if R_21 should be removed
# Finish updating diffalg
# Try to reduce R_23
# --- R_23 is a subexpr of some marked general laws in {'R_06', 'R_28', 'R_09'}
# Total rewards: 5

# %%
G = debugger.check_concept_discovered(Intrinsic(f"[#celestial_2_xy |- - (D[({(sum_tx+ sum_ty)()})]/D[(({dist(1, 2)} ** -1) + ({dist(2, 1)} ** -1))] / ({mass(1)} * {mass(2)}))]"), "G")
sum_vG = debugger.check_concept_discovered(f"[Sum:Particle] (1->Particle) (2->Particle) |- (({dist(1, 2)} ** -1) * ({G()} * ({mass(1)} * {mass(2)})))", "sum_vG")
G, sum_vG
# Out:
# (-C_59, -C_60)

# %%
prop_tx_ty_tz_2mgz_vk_vG = debugger.check_law((sum_tx + sum_ty + tz_2mgz + sum_vspring + sum_vG).gen_prop("Conserved"))
prop_tx_ty_tz_2mgz_vk_vG
# Out:
# 'R_28'

# %%
prop_tx_vG = debugger.check_law((sum_tx + sum_vG).gen_prop("Conserved"))
prop_tx_vG

# %% [markdown]
# inspect which experiments are now not covered by energy conservation now

# %%
print(debugger.law_info(prop_tx_ty_tz_2mgz_vk_vG))
# Out:
# GeneralLaw(name=R_28, type=IsConserved, indication=Sum, prop=|- ((-1 * C_60) + (C_53 + (C_31 + (C_20 + (-1 * C_28))))) is conserved, valid_experiments=['celestial_2_xy', 'motion', 'collision', 'oscillation', 'motiony', 'oscillationy', 'stringmotion0', 'motion0', 'motion0y', 'motion0_3d', 'motion_3d', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'collision_nh', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'hanging_spring_1', 'hanging_spring_2', 'hanging_spring_3', 'pendulum_oscillation_1', 'pendulum_oscillation_2', 'slope_oscillation_1', 'slope_oscillation_2', 'projectile_oscillation_1', 'projectile_oscillation_2', 'oscillation_x_1', 'oscillation_x_2', 'oscillation_x_3', 'oscillation_2d_1', 'oscillation_2d_2', 'oscillation_2d_3', 'oscillation_r_3', 'oscillation_r_4', 'oscillation_rot_1', 'oscillation_rot_2', 'oscillation_rot_3', 'celestial_3', 'celestial_4'], father=R_19)
# |- ((-1 * C_60) + (C_53 + (C_31 + (C_20 + (-1 * C_28))))) is conserved
# |- ((-1 * C_60) + (C_53 + (C_31 + (C_20 + (-1 * C_28))))) is conserved
# Not valid experiments: [celestial_2_yz, celestial_2_xz]

# %%
temp_expr = 2 * ax(1) + Exp.Partial(sum_vspring(), posx(1).unwrap_atom) / mass(1) + Exp.Partial(sum_vG(), posx(1).unwrap_atom) / mass(1)
print(temp_expr)
prop_ax_partvk_vG = debugger.check_law(f"(1->Particle) |- {temp_expr} is zero")
prop_ax_partvk_vG
# Out:
# ((Partial[(-C_60)]/Partial[posx[1]] / C_06[1]) + ((2 * C_10[1]) + (Partial[(-C_28)]/Partial[posx[1]] / C_06[1])))
# 'R_26'

# %% [markdown]
# inspect which experiments are now not covered by Newton's second law in $x$ direction now

# %%
print(debugger.law_info(prop_ax_partvk_vG))
# Out:
# GeneralLaw(name=R_26, type=IsZero, indication=ForAll, prop=(1->Particle) |- ((-1 * (Partial[C_60]/Partial[posx[1]] * (C_06[1] ** -1))) + ((2 * C_10[1]) + (-1 * (Partial[C_28]/Partial[posx[1]] * (C_06[1] ** -1))))) is zero, valid_experiments=['celestial_2_xy', 'collision', 'oscillation', 'motiony', 'oscillationy', 'motion0', 'motion0y', 'motion0_3d', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'hanging_spring_1', 'hanging_spring_2', 'hanging_spring_3', 'pendulum_oscillation_1', 'pendulum_oscillation_2', 'projectile_oscillation_1', 'projectile_oscillation_2', 'oscillation_x_1', 'oscillation_x_2', 'oscillation_x_3', 'oscillation_2d_1', 'oscillation_2d_2', 'oscillation_2d_3', 'oscillation_r_3', 'oscillation_r_4', 'oscillation_rot_1', 'oscillation_rot_2', 'oscillation_rot_3', 'celestial_2_xz', 'celestial_2_yz', 'celestial_3', 'celestial_4'], father=R_08)
# (1->Particle) |- ((-1 * (Partial[C_60]/Partial[posx[1]] * (C_06[1] ** -1))) + ((2 * C_10[1]) + (-1 * (Partial[C_28]/Partial[posx[1]] * (C_06[1] ** -1))))) is zero
# (1->Particle) |- ((-1 * (Partial[C_60]/Partial[posx[1]] * (C_06[1] ** -1))) + ((2 * D^2[posx[1]]/D[t[0]]^2) + (-1 * (Partial[C_28]/Partial[posx[1]] * (C_06[1] ** -1))))) is zero
# Not valid experiments: [slope_oscillation_1, stringmotion0, motion, slope_oscillation_2, collision_nh, motion_3d]

# %%
temp_expr = 2 * ay(1) + Exp.Partial(sum_vG(), posy(1).unwrap_atom) / mass(1)
print(temp_expr)
prop_ay_vG = debugger.check_law(f"(1->Particle) |- {temp_expr} is zero")
prop_ay_vG
# Out:
# ((2 * C_08[1]) + (Partial[(-C_60)]/Partial[posy[1]] / C_06[1]))
# 'R_24'

# %% [markdown]
# inspect which experiments are now not covered by Newton's second law in $y$ direction now

# %%
print(debugger.law_info(prop_ay_vG))
# Out:
# GeneralLaw(name=R_24, type=IsZero, indication=ForAll, prop=(1->Particle) |- ((2 * C_08[1]) + (-1 * (Partial[C_60]/Partial[posy[1]] * (C_06[1] ** -1)))) is zero, valid_experiments=['celestial_2_xy', 'motion', 'collision', 'oscillation', 'motion0', 'motion0y', 'motion0_3d', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'collision_nh', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'hanging_spring_1', 'hanging_spring_2', 'hanging_spring_3', 'pendulum_oscillation_1', 'pendulum_oscillation_2', 'oscillation_x_1', 'oscillation_x_2', 'oscillation_x_3', 'celestial_2_xz', 'celestial_2_yz', 'celestial_3', 'celestial_4'], father=R_01)
# (1->Particle) |- ((2 * C_08[1]) + (-1 * (Partial[C_60]/Partial[posy[1]] * (C_06[1] ** -1)))) is zero
# (1->Particle) |- ((2 * D^2[posy[1]]/D[t[0]]^2) + (-1 * (Partial[C_60]/Partial[posy[1]] * (C_06[1] ** -1)))) is zero
# Not valid experiments: [oscillation_2d_1, motiony, slope_oscillation_1, oscillation_r_3, stringmotion0, oscillation_2d_3, motion_3d, projectile_oscillation_1, oscillation_r_4, oscillationy, slope_oscillation_2, oscillation_rot_3, oscillation_2d_2, oscillation_rot_1, oscillation_rot_2, projectile_oscillation_2]

# %%
theorist.save_to_file("data/human/jds")
# Out:
# Saving knowledge to data/human/jds_knowledge.txt

# %% [markdown]
# ### find general conclusion: $\forall i\in\text{particles},\,a_{z,i} + F_{G,z}=const.$
#
# (Newton's second law in $z$ direction is now completed)

# %%
debugger.work("celestial_2_xz", name_list=[sum_vG, t])
# Out:
# ########## celestial_2_xz ##########
#
#
# Process ID: 1943844 of experiment celestial_2_xz
# Selected concepts: ['t', 'C_60']
# Try to complete invalid general laws
# - Try to complete R_02
# Registered new general law: R_30 = GeneralLaw(name=R_30, type=IsZero, indication=ForAll, prop=(1->Particle) |- ((2 * C_10[1]) + (-1 * (Partial[C_60]/Partial[posx[1]] * (C_06[1] ** -1)))) is zero, valid_experiments=['celestial_2_xz'], father=R_02)
# - Try to complete R_03
# Registered new general law: R_31 = GeneralLaw(name=R_31, type=IsConserved, indication=ForAll, prop=(1->Particle) |- ((2 * C_16[1]) + (-1 * (Partial[C_60]/Partial[posz[1]] * (C_06[1] ** -1)))) is conserved, valid_experiments=['celestial_2_xz'], father=R_03)
# - Try to complete R_05
# - Try to complete R_07
# - Try to complete R_08
# - Try to complete R_11
# - Try to complete R_12
# - Try to complete R_13
# - Try to complete R_15
# - Try to complete R_19
# - Try to complete R_21
# - Try to complete R_28
# Finish trying to complete incomplete general laws
# Fixing general laws.
# Try to convert conserved general laws to zero ones
# Finish trying to convert conserved general laws to zero ones
# Found 2 relations
# Begin filtering relations
# After filtering, 3 relations left
# Propose new proposition: posy[2] is zero
# Propose new proposition: posy[1] is zero
# Propose new proposition: (((dist[1, 2] ** 2) - ((posx[1] - posx[2]) ** 2)) - ((posz[1] - posz[2]) ** 2)) is zero
# Add to Specific model: 100%|██████████| 3/3 [00:00<00:00, 10600.60it/s]
# Reducing 4 conclusions
# Reduce Conclusions:  25%|██▌       | 1/4 [00:00<00:00,  6.13it/s]
# Insert to ideal: posy[1] is zero
# Reduce Conclusions:  25%|██▌       | 1/4 [00:00<00:00,  6.13it/s]
# Insert to ideal: posy[2] is zero
# Reduce Conclusions:  50%|█████     | 2/4 [00:00<00:00,  6.63it/s]
# Insert to ideal: (dist[1, 2] - dist[2, 1]) is zero
# Reduce Conclusions: 100%|██████████| 4/4 [00:00<00:00,  7.43it/s]
# Insert to ideal: (((dist[1, 2] ** 2) - ((posx[1] - posx[2]) ** 2)) - ((posz[1] - posz[2]) ** 2)) is zero
# calc_relations between  {'C_06[1]', 'C_06[2]'}
# Found 0 relations between conserved quantities
# Reducing 4 conclusions
# Reduce Conclusions:  25%|██▌       | 1/4 [00:00<00:00,  6.33it/s]
# Insert to ideal: posy[1] is zero
# Reduce Conclusions:  25%|██▌       | 1/4 [00:00<00:00,  6.33it/s]
# Insert to ideal: posy[2] is zero
# Reduce Conclusions:  50%|█████     | 2/4 [00:00<00:00,  6.72it/s]
# Insert to ideal: (dist[1, 2] - dist[2, 1]) is zero
# Reduce Conclusions: 100%|██████████| 4/4 [00:00<00:00,  7.62it/s]
# Insert to ideal: (((dist[1, 2] ** 2) - ((posx[1] - posx[2]) ** 2)) - ((posz[1] - posz[2]) ** 2)) is zero
# Fixing general laws.
# Try to reduce R_31
# --- R_31 is marked as useful
# Update diffalg for existing marked general laws
# Check if R_11 should be removed
# Check if R_12 should be removed
# Check if R_03 should be removed
# Finish updating diffalg
# Try to reduce R_30
# --- R_30 is a subexpr of some marked general laws in {'R_06', 'R_26'}
# Total rewards: 1

# %%
temp_expr = 2 * az(1) + Exp.Partial(sum_vG(), posz(1).unwrap_atom) / mass(1)
print(temp_expr)
prop_az_FG = debugger.check_law(f"(1->Particle) |- {temp_expr} is conserved")
prop_az_FG
# Out:
# ((2 * C_16[1]) + (Partial[(-C_60)]/Partial[posz[1]] / C_06[1]))
# 'R_31'

# %% [markdown]
# inspect which experiments are now not covered by Newton's second law in $z$ direction now

# %%
print(debugger.law_info(prop_az_FG))
# Out:
# GeneralLaw(name=R_31, type=IsConserved, indication=ForAll, prop=(1->Particle) |- ((2 * C_16[1]) + (-1 * (Partial[C_60]/Partial[posz[1]] * (C_06[1] ** -1)))) is conserved, valid_experiments=['celestial_2_xz', 'motion', 'collision', 'oscillation', 'motiony', 'oscillationy', 'motion0', 'motion0y', 'motion0_3d', 'motion_3d', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'collision_nh', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'oscillation_x_1', 'oscillation_x_2', 'oscillation_x_3', 'oscillation_2d_1', 'oscillation_2d_2', 'oscillation_2d_3', 'oscillation_r_3', 'oscillation_r_4', 'oscillation_rot_1', 'oscillation_rot_2', 'oscillation_rot_3', 'celestial_2_xy', 'celestial_2_yz', 'celestial_3', 'celestial_4'], father=R_03)
# (1->Particle) |- ((2 * C_16[1]) + (-1 * (Partial[C_60]/Partial[posz[1]] * (C_06[1] ** -1)))) is conserved
# (1->Particle) |- ((2 * D^2[posz[1]]/D[t[0]]^2) + (-1 * (Partial[C_60]/Partial[posz[1]] * (C_06[1] ** -1)))) is conserved
# Not valid experiments: [slope_oscillation_1, stringmotion0, pendulum_oscillation_2, projectile_oscillation_1, slope_oscillation_2, hanging_spring_1, pendulum_oscillation_1, hanging_spring_2, hanging_spring_3, projectile_oscillation_2]

# %% [markdown]
# ### save

# %%
theorist.save_to_file(debug_file)
# Out:
# Saving knowledge to data/human/jds_knowledge.txt

# %% [markdown]
# ## Test: Complete the Newton's second law in $x$ and $y$ directions

# %% [markdown]
# Newton's second law in $z$ direction is already completed

# %% [markdown]
# inspect which experiments are now not covered by Newton's second law in each direction

# %%
for prop in [prop_ax_partvk_vG, prop_ay_vG, prop_az_partvk_gz]:
    print(debugger.law_info(prop))
    print()
# Out:
# GeneralLaw(name=R_26, type=IsZero, indication=ForAll, prop=(1->Particle) |- ((-1 * (Partial[C_60]/Partial[posx[1]] * (C_06[1] ** -1))) + ((2 * C_10[1]) + (-1 * (Partial[C_28]/Partial[posx[1]] * (C_06[1] ** -1))))) is zero, valid_experiments=['celestial_2_xy', 'collision', 'oscillation', 'motiony', 'oscillationy', 'motion0', 'motion0y', 'motion0_3d', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'hanging_spring_1', 'hanging_spring_2', 'hanging_spring_3', 'pendulum_oscillation_1', 'pendulum_oscillation_2', 'projectile_oscillation_1', 'projectile_oscillation_2', 'oscillation_x_1', 'oscillation_x_2', 'oscillation_x_3', 'oscillation_2d_1', 'oscillation_2d_2', 'oscillation_2d_3', 'oscillation_r_3', 'oscillation_r_4', 'oscillation_rot_1', 'oscillation_rot_2', 'oscillation_rot_3', 'celestial_2_xz', 'celestial_2_yz', 'celestial_3', 'celestial_4'], father=R_08)
# (1->Particle) |- ((-1 * (Partial[C_60]/Partial[posx[1]] * (C_06[1] ** -1))) + ((2 * C_10[1]) + (-1 * (Partial[C_28]/Partial[posx[1]] * (C_06[1] ** -1))))) is zero
# (1->Particle) |- ((-1 * (Partial[C_60]/Partial[posx[1]] * (C_06[1] ** -1))) + ((2 * D^2[posx[1]]/D[t[0]]^2) + (-1 * (Partial[C_28]/Partial[posx[1]] * (C_06[1] ** -1))))) is zero
# Not valid experiments: [slope_oscillation_1, stringmotion0, motion, slope_oscillation_2, collision_nh, motion_3d]
#
# GeneralLaw(name=R_24, type=IsZero, indication=ForAll, prop=(1->Particle) |- ((2 * C_08[1]) + (-1 * (Partial[C_60]/Partial[posy[1]] * (C_06[1] ** -1)))) is zero, valid_experiments=['celestial_2_xy', 'motion', 'collision', 'oscillation', 'motion0', 'motion0y', 'motion0_3d', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'collision_nh', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'hanging_spring_1', 'hanging_spring_2', 'hanging_spring_3', 'pendulum_oscillation_1', 'pendulum_oscillation_2', 'oscillation_x_1', 'oscillation_x_2', 'oscillation_x_3', 'celestial_2_xz', 'celestial_2_yz', 'celestial_3', 'celestial_4'], father=R_01)
# (1->Particle) |- ((2 * C_08[1]) + (-1 * (Partial[C_60]/Partial[posy[1]] * (C_06[1] ** -1)))) is zero
# (1->Particle) |- ((2 * D^2[posy[1]]/D[t[0]]^2) + (-1 * (Partial[C_60]/Partial[posy[1]] * (C_06[1] ** -1)))) is zero
# Not valid experiments: [oscillation_2d_1, motiony, slope_oscillation_1, oscillation_r_3, stringmotion0, oscillation_2d_3, motion_3d, projectile_oscillation_1, oscillation_r_4, oscillationy, slope_oscillation_2, oscillation_rot_3, oscillation_2d_2, oscillation_rot_1, oscillation_rot_2, projectile_oscillation_2]
#
# GeneralLaw(name=R_21, type=IsZero, indication=ForAll, prop=(1->Particle) |- (Partial[C_46[1]]/Partial[posz[1]] + ((2 * C_16[1]) + (-1 * (Partial[C_28]/Partial[posz[1]] * (C_06[1] ** -1))))) is zero, valid_experiments=['hanging_spring_1', 'motion', 'collision', 'oscillation', 'motiony', 'oscillationy', 'motion0', 'motion0y', 'motion0_3d', 'motion_3d', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'collision_nh', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'hanging_spring_2', 'hanging_spring_3', 'pendulum_oscillation_1', 'pendulum_oscillation_2', 'slope_oscillation_1', 'slope_oscillation_2', 'projectile_oscillation_1', 'projectile_oscillation_2', 'oscillation_x_1', 'oscillation_x_2', 'oscillation_x_3', 'oscillation_2d_1', 'oscillation_2d_2', 'oscillation_2d_3', 'oscillation_r_3', 'oscillation_r_4', 'oscillation_rot_1', 'oscillation_rot_2', 'oscillation_rot_3', 'celestial_2_xy', 'celestial_3', 'celestial_4'], father=R_03)
# (1->Particle) |- (Partial[C_46[1]]/Partial[posz[1]] + ((2 * C_16[1]) + (-1 * (Partial[C_28]/Partial[posz[1]] * (C_06[1] ** -1))))) is zero
# (1->Particle) |- (((2 * D^2[posz[1]]/D[t[0]]^2) + (-1 * (Partial[C_28]/Partial[posz[1]] * (C_06[1] ** -1)))) + Partial[((D[posz[1]]/D[t[0]] * D[posz[1]]/D[t[0]]) - (2 * (C_44 * posz[1])))]/Partial[posz[1]]) is zero
# Not valid experiments: [celestial_2_yz, celestial_2_xz, stringmotion0]

# %% [markdown]
# ### find general conclusion: $\forall i\in\text{particles},\,a_{x,i}+\frac{1}{m_i}\frac{\partial \sum_{j\in\text{springs}}V^{(\text{spring})}_{j}}{\partial x_i} + F_{g,x,i} + F_{G}=0.$
#
# ### find general conclusion: $\forall i\in\text{particles},\,a_{y,i}+F_{g,y,i} + F_G=0.$
#
# (Newton's second law in $x$ direction is now completed)

# %%
debugger.work("motion_3d", name_list=[t, vzsq_plus_2gz])
theorist.save_to_file(debug_file)
# Out:
# ########## motion_3d ##########
#
#
# Process ID: 1943844 of experiment motion_3d
# Selected concepts: ['t', 'C_46']
# Try to complete invalid general laws
# - Try to complete R_01
# Registered new general law: R_49 = GeneralLaw(name=R_49, type=IsZero, indication=ForAll, prop=(1->Particle) |- ((2 * C_08[1]) + Partial[C_46[1]]/Partial[posy[1]]) is zero, valid_experiments=['motion_3d'], father=R_01)
# - Try to complete R_02
# Registered new general law: R_50 = GeneralLaw(name=R_50, type=IsZero, indication=ForAll, prop=(1->Particle) |- ((2 * C_10[1]) + Partial[C_46[1]]/Partial[posx[1]]) is zero, valid_experiments=['motion_3d'], father=R_02)
# - Try to complete R_05
# - Try to complete R_06
# - Try to complete R_07
# - Try to complete R_08
# Registered new general law: R_51 = GeneralLaw(name=R_51, type=IsZero, indication=ForAll, prop=(1->Particle) |- (Partial[C_46[1]]/Partial[posx[1]] + ((2 * C_10[1]) + (-1 * (Partial[C_28]/Partial[posx[1]] * (C_06[1] ** -1))))) is zero, valid_experiments=['motion_3d'], father=R_08)
# - Try to complete R_09
# - Try to complete R_10
# - Try to complete R_11
# - Try to complete R_13
# Registered new general law: R_52 = GeneralLaw(name=R_52, type=IsConserved, indication=Sum, prop=|- (C_53 + (C_20 + C_31)) is conserved, valid_experiments=['motion_3d'], father=R_13)
# - Try to complete R_15
# - Try to complete R_24
# Registered new general law: R_53 = GeneralLaw(name=R_53, type=IsZero, indication=ForAll, prop=(1->Particle) |- (Partial[C_46[1]]/Partial[posy[1]] + ((2 * C_08[1]) + (-1 * (Partial[C_60]/Partial[posy[1]] * (C_06[1] ** -1))))) is zero, valid_experiments=['motion_3d'], father=R_24)
# - Try to complete R_26
# Registered new general law: R_54 = GeneralLaw(name=R_54, type=IsZero, indication=ForAll, prop=(1->Particle) |- (Partial[C_46[1]]/Partial[posx[1]] + ((-1 * (Partial[C_60]/Partial[posx[1]] * (C_06[1] ** -1))) + ((2 * C_10[1]) + (-1 * (Partial[C_28]/Partial[posx[1]] * (C_06[1] ** -1)))))) is zero, valid_experiments=['motion_3d'], father=R_26)
# - Try to complete R_27
# Finish trying to complete incomplete general laws
# Fixing general laws.
# Try to convert conserved general laws to zero ones
# Finish trying to convert conserved general laws to zero ones
# Found 8 relations
# Begin filtering relations
# After filtering, 5 relations left
# Propose new proposition: cz[2] is conserved
# Propose new proposition: cx[2] is conserved
# Propose new proposition: cy[2] is conserved
# Propose new proposition: ((cy[2] * posx[1]) - (cx[2] * posy[1])) is conserved
# Propose new proposition: (((cx[2] * posx[1]) + (cy[2] * posy[1])) + (cz[2] * posz[1])) is conserved
# Add to Specific model: 100%|██████████| 5/5 [00:00<00:00, 9920.30it/s]
# Reducing 9 conclusions
# Reduce Conclusions:   0%|          | 0/9 [00:00<?, ?it/s]
# Insert to ideal: cx[2] is conserved
# Reduce Conclusions:  11%|█         | 1/9 [00:00<00:03,  2.16it/s]
# Insert to ideal: cy[2] is conserved
# Reduce Conclusions:  22%|██▏       | 2/9 [00:01<00:03,  2.16it/s]
# Insert to ideal: cz[2] is conserved
# Reduce Conclusions:  33%|███▎      | 3/9 [00:01<00:02,  2.22it/s]
# Insert to ideal: D[C_14[1]]/D[t[0]] is conserved
# Reduce Conclusions:  44%|████▍     | 4/9 [00:02<00:02,  1.77it/s]
# Insert to ideal: D[C_09[1]]/D[t[0]] is conserved
# Reduce Conclusions:  56%|█████▌    | 5/9 [00:03<00:02,  1.60it/s]
# Insert to ideal: D[posy[1]]/D[posx[1]] is conserved
# Reduce Conclusions:  67%|██████▋   | 6/9 [00:03<00:02,  1.49it/s]
# Insert to ideal: D[posz[1]]/D[posx[1]] is conserved
# Reduce Conclusions:  78%|███████▊  | 7/9 [00:04<00:01,  1.44it/s]
# Insert to ideal: ((cy[2] * posx[1]) - (cx[2] * posy[1])) is conserved
# Reduce Conclusions: 100%|██████████| 9/9 [00:05<00:00,  1.65it/s]
# Insert to ideal: (((cx[2] * posx[1]) + (cy[2] * posy[1])) + (cz[2] * posz[1])) is conserved
# calc_relations between  {'P8', 'P7', 'P5', 'P2', 'P6', 'C_06[1]', 'P1', 'P4', 'P3', 'P9'}
# Found 0 relations between conserved quantities
# Reducing 9 conclusions
# Reduce Conclusions:   0%|          | 0/9 [00:00<?, ?it/s]
# Insert to ideal: cx[2] is conserved
# Reduce Conclusions:  11%|█         | 1/9 [00:00<00:03,  2.12it/s]
# Insert to ideal: cy[2] is conserved
# Reduce Conclusions:  22%|██▏       | 2/9 [00:01<00:03,  2.17it/s]
# Insert to ideal: cz[2] is conserved
# Reduce Conclusions:  33%|███▎      | 3/9 [00:01<00:02,  2.19it/s]
# Insert to ideal: D[C_14[1]]/D[t[0]] is conserved
# Reduce Conclusions:  44%|████▍     | 4/9 [00:02<00:02,  1.75it/s]
# Insert to ideal: D[C_09[1]]/D[t[0]] is conserved
# Reduce Conclusions:  56%|█████▌    | 5/9 [00:03<00:02,  1.57it/s]
# Insert to ideal: D[posy[1]]/D[posx[1]] is conserved
# Reduce Conclusions:  67%|██████▋   | 6/9 [00:03<00:02,  1.49it/s]
# Insert to ideal: D[posz[1]]/D[posx[1]] is conserved
# Reduce Conclusions:  78%|███████▊  | 7/9 [00:04<00:01,  1.44it/s]
# Insert to ideal: ((cy[2] * posx[1]) - (cx[2] * posy[1])) is conserved
# Reduce Conclusions: 100%|██████████| 9/9 [00:05<00:00,  1.65it/s]
# Insert to ideal: (((cx[2] * posx[1]) + (cy[2] * posy[1])) + (cz[2] * posz[1])) is conserved
# Fixing general laws.
# Try to reduce R_53
# --- R_53 is marked as useful
# Update diffalg for existing marked general laws
# Check if R_01 should be removed
# Check if R_24 should be removed
# Finish updating diffalg
# Try to reduce R_54
# --- R_54 is marked as useful
# Update diffalg for existing marked general laws
# Check if R_26 should be removed
# --- R_26 is a subexpr of R_54
# --- R_26 is removed
# Finish updating diffalg
# Try to reduce R_51
# --- R_51 is a subexpr of some marked general laws in {'R_54'}
# Try to reduce R_50
# --- R_50 is a subexpr of some marked general laws in {'R_54'}
# Try to reduce R_52
# --- R_52 is a subexpr of some marked general laws in {'R_19', 'R_28'}
# Try to reduce R_49
# --- R_49 is a subexpr of some marked general laws in {'R_53'}
# Total rewards: 3
# Saving knowledge to data/human/jds_knowledge.txt

# %%
temp_expr = 2 * ax(1) + Exp.Partial(sum_vspring(), posx(1).unwrap_atom) / mass(1) + Exp.Partial(vzsq_plus_2gz(1), posx(1).unwrap_atom) + Exp.Partial(sum_vG(), posx(1).unwrap_atom) / mass(1)
print(temp_expr)
prop_ax_partvk_partvsq_2gz_FG = debugger.check_law(f"(1->Particle) |- {temp_expr} is zero")
prop_ax_partvk_partvsq_2gz_FG
# Out:
# ((Partial[(-C_60)]/Partial[posx[1]] / C_06[1]) + (Partial[C_46[1]]/Partial[posx[1]] + ((2 * C_10[1]) + (Partial[(-C_28)]/Partial[posx[1]] / C_06[1]))))
# 'R_54'

# %%
print(debugger.law_info(prop_ax_partvk_partvsq_2gz_FG))
# Out:
# GeneralLaw(name=R_54, type=IsZero, indication=ForAll, prop=(1->Particle) |- (Partial[C_46[1]]/Partial[posx[1]] + ((-1 * (Partial[C_60]/Partial[posx[1]] * (C_06[1] ** -1))) + ((2 * C_10[1]) + (-1 * (Partial[C_28]/Partial[posx[1]] * (C_06[1] ** -1)))))) is zero, valid_experiments=['motion_3d', 'motion', 'collision', 'oscillation', 'motiony', 'oscillationy', 'motion0', 'motion0y', 'motion0_3d', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'hanging_spring_1', 'hanging_spring_2', 'hanging_spring_3', 'pendulum_oscillation_1', 'pendulum_oscillation_2', 'slope_oscillation_1', 'slope_oscillation_2', 'projectile_oscillation_1', 'projectile_oscillation_2', 'oscillation_x_1', 'oscillation_x_2', 'oscillation_x_3', 'oscillation_2d_1', 'oscillation_2d_2', 'oscillation_2d_3', 'oscillation_r_3', 'oscillation_r_4', 'oscillation_rot_1', 'oscillation_rot_2', 'oscillation_rot_3', 'celestial_2_xy', 'celestial_2_xz', 'celestial_2_yz', 'celestial_3', 'celestial_4'], father=None)
# (1->Particle) |- (Partial[C_46[1]]/Partial[posx[1]] + ((-1 * (Partial[C_60]/Partial[posx[1]] * (C_06[1] ** -1))) + ((2 * C_10[1]) + (-1 * (Partial[C_28]/Partial[posx[1]] * (C_06[1] ** -1)))))) is zero
# (1->Particle) |- (Partial[((D[posz[1]]/D[t[0]] * D[posz[1]]/D[t[0]]) - (2 * (C_44 * posz[1])))]/Partial[posx[1]] + ((-1 * (Partial[C_60]/Partial[posx[1]] * (C_06[1] ** -1))) + ((2 * D^2[posx[1]]/D[t[0]]^2) + (-1 * (Partial[C_28]/Partial[posx[1]] * (C_06[1] ** -1)))))) is zero
# Not valid experiments: [collision_nh, stringmotion0]

# %%
temp_expr = 2 * ay(1) + Exp.Partial(vzsq_plus_2gz(1), posy(1).unwrap_atom) + Exp.Partial(sum_vG(), posy(1).unwrap_atom) / mass(1)
prop_ay_partvsq_2gz_FG = debugger.check_law(f"(1->Particle) |- {temp_expr} is zero")
prop_ay_partvsq_2gz_FG
# Out:
# 'R_53'

# %% [markdown]
# inspect which experiments are now not covered by Newton's second law in $y$ direction now

# %%
print(debugger.law_info(prop_ay_partvsq_2gz_FG))
# Out:
# GeneralLaw(name=R_53, type=IsZero, indication=ForAll, prop=(1->Particle) |- (Partial[C_46[1]]/Partial[posy[1]] + ((2 * C_08[1]) + (-1 * (Partial[C_60]/Partial[posy[1]] * (C_06[1] ** -1))))) is zero, valid_experiments=['motion_3d', 'motion', 'collision', 'oscillation', 'motiony', 'motion0', 'motion0y', 'motion0_3d', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'collision_nh', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'hanging_spring_1', 'hanging_spring_2', 'hanging_spring_3', 'pendulum_oscillation_1', 'pendulum_oscillation_2', 'oscillation_x_1', 'oscillation_x_2', 'oscillation_x_3', 'celestial_2_xy', 'celestial_2_xz', 'celestial_2_yz', 'celestial_3', 'celestial_4'], father=R_24)
# (1->Particle) |- (Partial[C_46[1]]/Partial[posy[1]] + ((2 * C_08[1]) + (-1 * (Partial[C_60]/Partial[posy[1]] * (C_06[1] ** -1))))) is zero
# (1->Particle) |- (((2 * D^2[posy[1]]/D[t[0]]^2) + (-1 * (Partial[C_60]/Partial[posy[1]] * (C_06[1] ** -1)))) + Partial[((D[posz[1]]/D[t[0]] * D[posz[1]]/D[t[0]]) - (2 * (C_44 * posz[1])))]/Partial[posy[1]]) is zero
# Not valid experiments: [oscillation_2d_1, slope_oscillation_1, oscillation_r_3, stringmotion0, oscillation_2d_3, projectile_oscillation_1, oscillation_r_4, oscillationy, slope_oscillation_2, oscillation_rot_3, oscillation_2d_2, oscillation_rot_1, oscillation_rot_2, projectile_oscillation_2]

# %% [markdown]
# ### find general conclusion: $\forall i\in\text{particles},\,a_{y,i} + \frac{1}{m_i}\frac{\partial \sum_{j\in\text{springs}}V^{(\text{spring})}_{j}}{\partial y_i} +F_{g,y,i} + F_G=0.$
#
# Newton's second law in $y$ direction is now completed
#
# (Some byproducts are found)

# %%
debugger.work("oscillation_2d_1", name_list=[sum_vspring, t])
# Out:
# ########## oscillation_2d_1 ##########
#
#
# Process ID: 1943844 of experiment oscillation_2d_1
# Selected concepts: ['t', 'C_28']
# Try to complete invalid general laws
# - Try to complete R_01
# Registered new general law: R_56 = GeneralLaw(name=R_56, type=IsZero, indication=ForAll, prop=(1->Particle) |- ((2 * C_08[1]) + (-1 * (Partial[C_28]/Partial[posy[1]] * (C_06[1] ** -1)))) is zero, valid_experiments=['oscillation_2d_1'], father=R_01)
# - Try to complete R_02
# - Try to complete R_05
# - Try to complete R_07
# - Try to complete R_10
# - Try to complete R_13
# Registered new general law: R_59 = GeneralLaw(name=R_59, type=IsConserved, indication=Sum, prop=|- ((C_20 + C_31) + (-1 * C_28)) is conserved, valid_experiments=['oscillation_2d_1'], father=R_13)
# - Try to complete R_15
# Registered new general law: R_60 = GeneralLaw(name=R_60, type=IsConserved, indication=Sum, prop=|- ((-1 * C_28) + (C_52 + (C_20 + C_31))) is conserved, valid_experiments=['oscillation_2d_1'], father=R_15)
# - Try to complete R_24
# Registered new general law: R_61 = GeneralLaw(name=R_61, type=IsZero, indication=ForAll, prop=(1->Particle) |- ((-1 * (Partial[C_28]/Partial[posy[1]] * (C_06[1] ** -1))) + ((2 * C_08[1]) + (-1 * (Partial[C_60]/Partial[posy[1]] * (C_06[1] ** -1))))) is zero, valid_experiments=['oscillation_2d_1'], father=R_24)
# - Try to complete R_27
# Registered new general law: R_62 = GeneralLaw(name=R_62, type=IsConserved, indication=Sum, prop=|- ((-1 * C_28) + ((-1 * C_60) + (C_52 + (C_20 + C_31)))) is conserved, valid_experiments=['oscillation_2d_1'], father=R_27)
# - Try to complete R_53
# Registered new general law: R_63 = GeneralLaw(name=R_63, type=IsZero, indication=ForAll, prop=(1->Particle) |- ((-1 * (Partial[C_28]/Partial[posy[1]] * (C_06[1] ** -1))) + (Partial[C_46[1]]/Partial[posy[1]] + ((2 * C_08[1]) + (-1 * (Partial[C_60]/Partial[posy[1]] * (C_06[1] ** -1)))))) is zero, valid_experiments=['oscillation_2d_1'], father=R_53)
# Finish trying to complete incomplete general laws
# Fixing general laws.
# Try to convert conserved general laws to zero ones
# Finish trying to convert conserved general laws to zero ones
# Found 2 relations
# Begin filtering relations
# After filtering, 5 relations left
# Propose new proposition: posz[1] is zero
# Propose new proposition: posz[2] is zero
# Propose new proposition: (dist[1, 2] - length[3]) is zero
# Propose new proposition: (dist[1, 2] - dist[2, 1]) is zero
# Propose new proposition: (((dist[1, 2] ** 2) - ((posx[1] - posx[2]) ** 2)) - ((posy[1] - posy[2]) ** 2)) is zero
# Add to Specific model: 100%|██████████| 5/5 [00:00<00:00, 15307.68it/s]
# Reducing 5 conclusions
# Reduce Conclusions:  20%|██        | 1/5 [00:00<00:00,  6.66it/s]
# Insert to ideal: posz[1] is zero
# Reduce Conclusions:  20%|██        | 1/5 [00:00<00:00,  6.66it/s]
# Insert to ideal: posz[2] is zero
# Reduce Conclusions:  40%|████      | 2/5 [00:00<00:00,  6.51it/s]
# Insert to ideal: (dist[1, 2] - length[3]) is zero
# Reduce Conclusions:  60%|██████    | 3/5 [00:00<00:00,  6.61it/s]
# Insert to ideal: (dist[1, 2] - dist[2, 1]) is zero
# Reduce Conclusions: 100%|██████████| 5/5 [00:00<00:00,  7.19it/s]
# Insert to ideal: (((dist[1, 2] ** 2) - ((posx[1] - posx[2]) ** 2)) - ((posy[1] - posy[2]) ** 2)) is zero
# calc_relations between  {'C_06[1]', 'C_27[3]', 'C_06[2]', 'C_01[3]'}
# Found 0 relations between conserved quantities
# Reducing 5 conclusions
# Reduce Conclusions:  20%|██        | 1/5 [00:00<00:00,  6.98it/s]
# Insert to ideal: posz[1] is zero
# Reduce Conclusions:  20%|██        | 1/5 [00:00<00:00,  6.98it/s]
# Insert to ideal: posz[2] is zero
# Reduce Conclusions:  60%|██████    | 3/5 [00:00<00:00,  7.84it/s]
# Insert to ideal: (dist[1, 2] - length[3]) is zero
# Reduce Conclusions:  80%|████████  | 4/5 [00:00<00:00,  7.62it/s]
# Insert to ideal: (dist[1, 2] - dist[2, 1]) is zero
# Reduce Conclusions: 100%|██████████| 5/5 [00:00<00:00,  8.11it/s]
# Insert to ideal: (((dist[1, 2] ** 2) - ((posx[1] - posx[2]) ** 2)) - ((posy[1] - posy[2]) ** 2)) is zero
# Fixing general laws.
# Try to reduce R_59
# --- R_59 is a subexpr of some marked general laws in {'R_19', 'R_28'}
# Try to reduce R_63
# --- R_63 is marked as useful
# Update diffalg for existing marked general laws
# Check if R_02 should be removed
# Check if R_01 should be removed
# Check if R_11 should be removed
# Check if R_12 should be removed
# Check if R_08 should be removed
# Check if R_54 should be removed
# Check if R_53 should be removed
# --- R_53 is a subexpr of R_63
# --- R_53 is removed
# Check if R_24 should be removed
# Check if R_03 should be removed
# Check if R_21 should be removed
# Check if R_31 should be removed
# Finish updating diffalg
# Try to reduce R_61
# --- R_61 is a subexpr of some marked general laws in {'R_63'}
# Try to reduce R_56
# --- R_56 is a subexpr of some marked general laws in {'R_63'}
# Try to reduce R_62
# --- R_62 is marked as useful
# Update diffalg for existing marked general laws
# Check if R_27 should be removed
# Check if R_15 should be removed
# Finish updating diffalg
# Try to reduce R_60
# --- R_60 is a subexpr of some marked general laws in {'R_19', 'R_62', 'R_28'}
# Total rewards: 3

# %%
temp_expr = 2 * ay(1) + Exp.Partial(vzsq_plus_2gz(1), posy(1).unwrap_atom) + Exp.Partial(sum_vG(), posy(1).unwrap_atom) / mass(1) + Exp.Partial(sum_vspring(), posy(1).unwrap_atom) / mass(1)
print(temp_expr)
prop_ay_partvk_partvsq_2gz_FG = debugger.check_law(f"(1->Particle) |- {temp_expr} is zero")
prop_ay_partvk_partvsq_2gz_FG
# Out:
# ((Partial[(-C_28)]/Partial[posy[1]] / C_06[1]) + ((Partial[(-C_60)]/Partial[posy[1]] / C_06[1]) + ((2 * C_08[1]) + Partial[C_46[1]]/Partial[posy[1]])))
# 'R_63'

# %%
print(debugger.law_info(prop_ay_partvk_partvsq_2gz_FG))
# Out:
# GeneralLaw(name=R_63, type=IsZero, indication=ForAll, prop=(1->Particle) |- ((-1 * (Partial[C_28]/Partial[posy[1]] * (C_06[1] ** -1))) + (Partial[C_46[1]]/Partial[posy[1]] + ((2 * C_08[1]) + (-1 * (Partial[C_60]/Partial[posy[1]] * (C_06[1] ** -1)))))) is zero, valid_experiments=['oscillation_2d_1', 'motion', 'collision', 'oscillation', 'motiony', 'oscillationy', 'motion0', 'motion0y', 'motion0_3d', 'motion_3d', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'collision_nh', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'hanging_spring_1', 'hanging_spring_2', 'hanging_spring_3', 'pendulum_oscillation_1', 'pendulum_oscillation_2', 'slope_oscillation_1', 'slope_oscillation_2', 'projectile_oscillation_1', 'projectile_oscillation_2', 'oscillation_x_1', 'oscillation_x_2', 'oscillation_x_3', 'oscillation_2d_2', 'oscillation_2d_3', 'oscillation_r_3', 'oscillation_r_4', 'oscillation_rot_1', 'oscillation_rot_2', 'oscillation_rot_3', 'celestial_2_xy', 'celestial_2_xz', 'celestial_2_yz', 'celestial_3', 'celestial_4'], father=None)
# (1->Particle) |- ((-1 * (Partial[C_28]/Partial[posy[1]] * (C_06[1] ** -1))) + (Partial[C_46[1]]/Partial[posy[1]] + ((2 * C_08[1]) + (-1 * (Partial[C_60]/Partial[posy[1]] * (C_06[1] ** -1)))))) is zero
# (1->Particle) |- ((-1 * (Partial[C_28]/Partial[posy[1]] * (C_06[1] ** -1))) + (((2 * D^2[posy[1]]/D[t[0]]^2) + (-1 * (Partial[C_60]/Partial[posy[1]] * (C_06[1] ** -1)))) + Partial[((D[posz[1]]/D[t[0]] * D[posz[1]]/D[t[0]]) - (2 * (C_44 * posz[1])))]/Partial[posy[1]])) is zero
# Not valid experiments: [stringmotion0]

# %% [markdown]
# ### summarize

# %%
print(debugger.law_info(prop_ax_partvk_partvsq_2gz_FG))
# Out:
# GeneralLaw(name=R_54, type=IsZero, indication=ForAll, prop=(1->Particle) |- (Partial[C_46[1]]/Partial[posx[1]] + ((-1 * (Partial[C_60]/Partial[posx[1]] * (C_06[1] ** -1))) + ((2 * C_10[1]) + (-1 * (Partial[C_28]/Partial[posx[1]] * (C_06[1] ** -1)))))) is zero, valid_experiments=['motion_3d', 'motion', 'collision', 'oscillation', 'motiony', 'oscillationy', 'motion0', 'motion0y', 'motion0_3d', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'hanging_spring_1', 'hanging_spring_2', 'hanging_spring_3', 'pendulum_oscillation_1', 'pendulum_oscillation_2', 'slope_oscillation_1', 'slope_oscillation_2', 'projectile_oscillation_1', 'projectile_oscillation_2', 'oscillation_x_1', 'oscillation_x_2', 'oscillation_x_3', 'oscillation_2d_1', 'oscillation_2d_2', 'oscillation_2d_3', 'oscillation_r_3', 'oscillation_r_4', 'oscillation_rot_1', 'oscillation_rot_2', 'oscillation_rot_3', 'celestial_2_xy', 'celestial_2_xz', 'celestial_2_yz', 'celestial_3', 'celestial_4'], father=None)
# (1->Particle) |- (Partial[C_46[1]]/Partial[posx[1]] + ((-1 * (Partial[C_60]/Partial[posx[1]] * (C_06[1] ** -1))) + ((2 * C_10[1]) + (-1 * (Partial[C_28]/Partial[posx[1]] * (C_06[1] ** -1)))))) is zero
# (1->Particle) |- (Partial[((D[posz[1]]/D[t[0]] * D[posz[1]]/D[t[0]]) - (2 * (C_44 * posz[1])))]/Partial[posx[1]] + ((-1 * (Partial[C_60]/Partial[posx[1]] * (C_06[1] ** -1))) + ((2 * D^2[posx[1]]/D[t[0]]^2) + (-1 * (Partial[C_28]/Partial[posx[1]] * (C_06[1] ** -1)))))) is zero
# Not valid experiments: [collision_nh, stringmotion0]

# %%
print(debugger.law_info(prop_ay_partvk_partvsq_2gz_FG))
# Out:
# GeneralLaw(name=R_63, type=IsZero, indication=ForAll, prop=(1->Particle) |- ((-1 * (Partial[C_28]/Partial[posy[1]] * (C_06[1] ** -1))) + (Partial[C_46[1]]/Partial[posy[1]] + ((2 * C_08[1]) + (-1 * (Partial[C_60]/Partial[posy[1]] * (C_06[1] ** -1)))))) is zero, valid_experiments=['oscillation_2d_1', 'motion', 'collision', 'oscillation', 'motiony', 'oscillationy', 'motion0', 'motion0y', 'motion0_3d', 'motion_3d', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'collision_nh', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'hanging_spring_1', 'hanging_spring_2', 'hanging_spring_3', 'pendulum_oscillation_1', 'pendulum_oscillation_2', 'slope_oscillation_1', 'slope_oscillation_2', 'projectile_oscillation_1', 'projectile_oscillation_2', 'oscillation_x_1', 'oscillation_x_2', 'oscillation_x_3', 'oscillation_2d_2', 'oscillation_2d_3', 'oscillation_r_3', 'oscillation_r_4', 'oscillation_rot_1', 'oscillation_rot_2', 'oscillation_rot_3', 'celestial_2_xy', 'celestial_2_xz', 'celestial_2_yz', 'celestial_3', 'celestial_4'], father=None)
# (1->Particle) |- ((-1 * (Partial[C_28]/Partial[posy[1]] * (C_06[1] ** -1))) + (Partial[C_46[1]]/Partial[posy[1]] + ((2 * C_08[1]) + (-1 * (Partial[C_60]/Partial[posy[1]] * (C_06[1] ** -1)))))) is zero
# (1->Particle) |- ((-1 * (Partial[C_28]/Partial[posy[1]] * (C_06[1] ** -1))) + (((2 * D^2[posy[1]]/D[t[0]]^2) + (-1 * (Partial[C_60]/Partial[posy[1]] * (C_06[1] ** -1)))) + Partial[((D[posz[1]]/D[t[0]] * D[posz[1]]/D[t[0]]) - (2 * (C_44 * posz[1])))]/Partial[posy[1]])) is zero
# Not valid experiments: [stringmotion0]

# %%
print(debugger.law_info(prop_az_partvk_gz))
# Out:
# GeneralLaw(name=R_21, type=IsZero, indication=ForAll, prop=(1->Particle) |- (Partial[C_46[1]]/Partial[posz[1]] + ((2 * C_16[1]) + (-1 * (Partial[C_28]/Partial[posz[1]] * (C_06[1] ** -1))))) is zero, valid_experiments=['hanging_spring_1', 'motion', 'collision', 'oscillation', 'motiony', 'oscillationy', 'motion0', 'motion0y', 'motion0_3d', 'motion_3d', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'collision_nh', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'hanging_spring_2', 'hanging_spring_3', 'pendulum_oscillation_1', 'pendulum_oscillation_2', 'slope_oscillation_1', 'slope_oscillation_2', 'projectile_oscillation_1', 'projectile_oscillation_2', 'oscillation_x_1', 'oscillation_x_2', 'oscillation_x_3', 'oscillation_2d_1', 'oscillation_2d_2', 'oscillation_2d_3', 'oscillation_r_3', 'oscillation_r_4', 'oscillation_rot_1', 'oscillation_rot_2', 'oscillation_rot_3', 'celestial_2_xy', 'celestial_3', 'celestial_4'], father=R_03)
# (1->Particle) |- (Partial[C_46[1]]/Partial[posz[1]] + ((2 * C_16[1]) + (-1 * (Partial[C_28]/Partial[posz[1]] * (C_06[1] ** -1))))) is zero
# (1->Particle) |- (((2 * D^2[posz[1]]/D[t[0]]^2) + (-1 * (Partial[C_28]/Partial[posz[1]] * (C_06[1] ** -1)))) + Partial[((D[posz[1]]/D[t[0]] * D[posz[1]]/D[t[0]]) - (2 * (C_44 * posz[1])))]/Partial[posz[1]]) is zero
# Not valid experiments: [celestial_2_yz, celestial_2_xz, stringmotion0]

# %%
print(debugger.law_info(prop_az_FG))
# Out:
# GeneralLaw(name=R_31, type=IsConserved, indication=ForAll, prop=(1->Particle) |- ((2 * C_16[1]) + (-1 * (Partial[C_60]/Partial[posz[1]] * (C_06[1] ** -1)))) is conserved, valid_experiments=['celestial_2_xz', 'motion', 'collision', 'oscillation', 'motiony', 'oscillationy', 'motion0', 'motion0y', 'motion0_3d', 'motion_3d', 'collision_elastic_3body', 'collision_y', 'collision_2d', 'collision_nh', 'gravity', 'free_fall', 'projectile', 'oblique_projectile_x', 'oblique_projectile_y', 'oblique_projectile', 'vertical_projectile', 'oscillation_x_1', 'oscillation_x_2', 'oscillation_x_3', 'oscillation_2d_1', 'oscillation_2d_2', 'oscillation_2d_3', 'oscillation_r_3', 'oscillation_r_4', 'oscillation_rot_1', 'oscillation_rot_2', 'oscillation_rot_3', 'celestial_2_xy', 'celestial_2_yz', 'celestial_3', 'celestial_4'], father=R_03)
# (1->Particle) |- ((2 * C_16[1]) + (-1 * (Partial[C_60]/Partial[posz[1]] * (C_06[1] ** -1)))) is conserved
# (1->Particle) |- ((2 * D^2[posz[1]]/D[t[0]]^2) + (-1 * (Partial[C_60]/Partial[posz[1]] * (C_06[1] ** -1)))) is conserved
# Not valid experiments: [slope_oscillation_1, stringmotion0, pendulum_oscillation_2, projectile_oscillation_1, slope_oscillation_2, hanging_spring_1, pendulum_oscillation_1, hanging_spring_2, hanging_spring_3, projectile_oscillation_2]

# %% [markdown]
# ### save

# %%
theorist.save_to_file(debug_file)
# Out:
# Saving knowledge to data/human/jds_knowledge.txt
